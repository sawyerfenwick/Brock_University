# %% [markdown]
# # Goal: students will implement a basic relational algebra system using Python.

# %% [markdown]
# ## Loading Data
#
# We will read from csv files into lists

# %%
import csv
import operator #For Selection Modes

def open_file(filename):
    with open(filename, 'r', newline = '') as f:
        reader = csv.reader(f, delimiter='\t')
        data = list(reader)
        return data[1:]

# %%
# Data source: https://relational.fit.cvut.cz/dataset/IMDb
# Information courtesy of IMDb (http://www.imdb.com). Used with permission.
# Notice: The data can only be used for personal and non-commercial use and must not
# be altered/republished/resold/repurposed to create any kind of online/offline
# database of movie information (except for individual personal use).

path = 'data/IMDb_sample'  
# create a list of all files in that directory that end with "*.csv":

actors = open_file(path + '/actors.csv')
directors_genres = open_file(path + '/directors_genres.csv')
directors = open_file(path + '/directors.csv')
movies_directors = open_file(path + '/movies_directors.csv')
movies_genres = open_file(path + '/movies_genres.csv')
movies = open_file(path + '/movies.csv')
roles = open_file(path + '/roles.csv')

# %%
actors
# Out:
# [['10963', 'Chris', 'Anastasio', 'M'],
#  ['32638', 'Michael', 'Beach', 'M'],
#  ['33949', 'John', 'Bedford Lloyd', 'M'],
#  ['42278', 'Michael', 'Biehn', 'M'],
#  ['57051', 'Captain Kidd', 'Brewer Jr.', 'M'],
#  ['64610', 'Leo', 'Burmester', 'M'],
#  ['69977', 'Mike (I)', 'Cameron', 'M'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M'],
#  ['81503', 'Michael (I)', 'Chapman', 'M'],
#  ['108530', 'Phillip', 'Darlington', 'M'],
#  ['130508', 'Thomas F.', 'Duffy', 'M'],
#  ['138073', 'Chris (I)', 'Elliott', 'M'],
#  ['145064', 'Joe', 'Farago', 'M'],
#  ['181264', 'Todd', 'Graff', 'M'],
#  ['197929', 'Ed (I)', 'Harris', 'M'],
#  ['223068', 'Tom', 'Isbell', 'M'],
#  ['228850', 'Ken (I)', 'Jenkins', 'M'],
#  ['250810', 'George Robert', 'Klek', 'M'],
#  ['281620', 'Frank (II)', 'Lloyd', 'M'],
#  ['334067', 'Marcus K.', 'Mukai', 'M'],
#  ['335612', 'Christopher (I)', 'Murphy', 'M'],
#  ['341916', 'Adam (I)', 'Nelson', 'M'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M'],
#  ['386373', 'J.C.', 'Quinn', 'M'],
#  ['391009', 'Peter', 'Ratray', 'M'],
#  ['459752', 'Brad', 'Sullivan', 'M'],
#  ['502273', 'Dick', 'Warlock', 'M'],
#  ['504906', 'Jimmie Ray', 'Weeks', 'M'],
#  ['514734', 'William', 'Wisher Jr.', 'M'],
#  ['589318', 'Paula', 'Cross', 'F'],
#  ['636502', 'Wendy', 'Gordon', 'F'],
#  ['712889', 'Mary Elizabeth', 'Mastrantonio', 'F'],
#  ['785706', 'Kimberly (I)', 'Scott', 'F'],
#  ['840493', 'Emily', 'Yancy', 'F'],
#  ['16844', 'William (I)', 'Armstrong', 'M'],
#  ['36641', 'Jay (I)', 'Benedict', 'M'],
#  ['144260', 'Blain', 'Fairman', 'M'],
#  ['204493', 'Christopher', 'Henn', 'M'],
#  ['204719', 'Lance', 'Henriksen', 'M'],
#  ['213646', 'William', 'Hope', 'M'],
#  ['240277', 'Daniel', 'Kash', 'M'],
#  ['272557', 'John', 'Lees', 'M'],
#  ['305705', 'Al', 'Matthews', 'M'],
#  ['306790', 'Paul (I)', 'Maxwell', 'M'],
#  ['310030', 'Mac (I)', 'McDonald', 'M'],
#  ['366173', 'Bill', 'Paxton', 'M'],
#  ['378476', 'Alan', 'Polonsky', 'M'],
#  ['394516', 'Paul', 'Reiser', 'M'],
#  ['405572', 'Mark', 'Rolston', 'M'],
#  ['408215', 'Ricco', 'Ross', 'M'],
#  ['452549', 'Trevor', 'Steedman', 'M'],
#  ['474375', 'Tip', 'Tipping', 'M'],
#  ['476429', 'Carl', 'Toop', 'M'],
#  ['583693', 'Barbara', 'Coles', 'F'],
#  ['583735', 'Valerie', 'Colgan', 'F'],
#  ['596318', 'Holly', 'De Jong', 'F'],
#  ['635153', 'Jenette', 'Goldstein', 'F'],
#  ['651551', 'Carrie', 'Henn', 'F'],
#  ['653997', 'Colette', 'Hiller', 'F'],
#  ['661430', 'Elizabeth', 'Inglis', 'F'],
#  ['748340', 'Alibe', 'Parsons', 'F'],
#  ['785581', 'Cynthia Dale', 'Scott', 'F'],
#  ['831289', 'Sigourney', 'Weaver', 'F'],
#  ['69940', 'James (I)', 'Cameron', 'M'],
#  ['128257', 'Richard', 'Doyle', 'M'],
#  ['137802', 'Bob', 'Elkins', 'M'],
#  ['185164', 'Fred', 'Griffith', 'M'],
#  ['232844', 'Dean (VII)', 'Jones', 'M'],
#  ['259373', 'Karl (II)', 'Kuhn', 'M'],
#  ['285456', 'Curt', 'Lowens', 'M'],
#  ['428322', 'Ty', 'Sears', 'M'],
#  ['432055', 'Chris', 'Shafer', 'M'],
#  ['452552', 'Heinz', 'Steeg', 'M'],
#  ['460992', 'Blake', 'Sutton', 'M'],
#  ['505504', 'Walter', 'Weintz', 'M'],
#  ['518333', 'Kai', 'Wulff', 'M'],
#  ['933', 'Lewis', 'Abernathy', 'M'],
#  ['16963', 'Charlie', 'Arneson', 'M'],
#  ['24256', 'Jesse (II)', 'Baker', 'M'],
#  ['24288', 'Justin (II)', 'Baker', 'M'],
#  ['58357', 'Dr. John', 'Broadwater', 'M'],
#  ['61439', 'John (I)', 'Bruno', 'M'],
#  ['83459', 'Genya', 'Chernaiev', 'M'],
#  ['126295', 'John (I)', 'Donovan', 'M'],
#  ['152244', 'Aaron C.', 'Fitzgerald', 'M'],
#  ['188927', 'Piper', 'Gunnarson', 'M'],
#  ['227895', 'Corey', 'Jaskolski', 'M'],
#  ['247406', 'Thomas', 'Kilroy', 'M'],
#  ['271226', 'Jeffrey N.', 'Ledda', 'M'],
#  ['288312', 'Don (II)', 'Lynch', 'M'],
#  ['300455', 'Ken', 'Marschall', 'M'],
#  ['346051', 'Victor', 'Nischeta', 'M'],
#  ['358828', 'Vince', 'Pace', 'M'],
#  ['365476', 'Jason (II)', 'Paul', 'M'],
#  ['367826', 'Charles (I)', 'Pellegrino', 'M'],
#  ['414913', 'Dr. Anatoly M.', 'Sagalevitch', 'M'],
#  ['424651', 'Eric', 'Schmitz', 'M'],
#  ['433468', 'Justin', 'Shaw', 'M'],
#  ['510823', 'Miguel', 'Wilkins', 'M'],
#  ['523925', 'Federico', 'Zambrano', 'M'],
#  ['649578', 'Stacey', 'Hayes', 'F'],
#  ['667425', 'Dr. Lori', 'Johnston', 'F'],
#  ['758870', 'Judy', 'Prestininzi', 'F'],
#  ['768452', 'Dale (II)', 'Ridge', 'F'],
#  ['794639', 'Tava', 'Smiley', 'F'],
#  ['809044', 'Janace', 'Tashjian', 'F'],
#  ['819988', 'Adriana', 'Valdez', 'F'],
#  ['91252', 'Phil', 'Colby', 'M'],
#  ['116418', 'Gaetano', 'Del Grande', 'M'],
#  ['129406', 'Paul', 'Drummond', 'M'],
#  ['175604', 'Ancile', 'Gloudon', 'M'],
#  ['176935', 'Ricky Paull', 'Goldin', 'M'],
#  ['223545', 'Paul', 'Issa', 'M'],
#  ['258459', 'Lee', 'Krug', 'M'],
#  ['297529', 'Steve', 'Marachuk', 'M'],
#  ['359763', 'Jim', 'Pair', 'M'],
#  ['388685', 'Johnny', 'Ralston', 'M'],
#  ['398113', 'Ted', 'Richert', 'M'],
#  ['407927', 'Arnie', 'Ross', 'M'],
#  ['418091', 'Albert (I)', 'Sanders', 'M'],
#  ['508939', 'Ward', 'White', 'M'],
#  ['521874', 'Aston S.', 'Young', 'M'],
#  ['551641', 'Tracey', 'Berg', 'F'],
#  ['590307', 'Dorothy', 'Cunningham', 'F'],
#  ['594608', 'Carole (I)', 'Davis', 'F'],
#  ['638349', 'Leslie (I)', 'Graves', 'F'],
#  ['643627', 'Connie Lynn', 'Hadden', 'F'],
#  ['705207', 'Hildy', 'Magnasun', 'F'],
#  ['707687', 'Jan Eisner', 'Mannon', 'F'],
#  ['741046', 'Tricia', "O'Neil", 'F'],
#  ['756625', 'Anne', 'Pollack', 'F'],
#  ['767575', 'Sally', 'Ricca', 'F'],
#  ['832066', 'Myra', 'Weisler', 'F'],
#  ['47595', 'Earl', 'Boen', 'M'],
#  ['103007', 'Jim', 'Cummings', 'M'],
#  ['162232', 'Edward', 'Furlong', 'M'],
#  ['257870', 'Mark', 'Kriski', 'M'],
#  ['364956', 'Robert (I)', 'Patrick', 'M'],
#  ['426628', 'Arnold', 'Schwarzenegger', 'M'],
#  ['645256', 'Linda (I)', 'Hamilton', 'F'],
#  ['450', 'Dalton', 'Abbott', 'M'],
#  ['17037', 'Bret A.', 'Arnold', 'M'],
#  ['39044', 'Xander', 'Berkeley', 'M'],
#  ['39129', 'Ennalls', 'Berl', 'M'],
#  ['59799', 'Charles Robert', 'Brown', 'M'],
#  ['82660', 'Casey', 'Chavez', 'M'],
#  ['95086', 'Danny', 'Cooksey', 'M'],
#  ['135826', 'Michael (I)', 'Edwards', 'M'],
#  ['137207', 'Abdul Salaam', 'El Razzac', 'M'],
#  ['142921', 'Terrence', 'Evans', 'M'],
#  ['172134', 'Ken', 'Gibbel', 'M'],
#  ['187569', 'Castulo', 'Guerra', 'M'],
#  ['233988', 'J. Rob', 'Jordan', 'M'],
#  ['255881', 'Pat', 'Kouri', 'M'],
#  ['263765', 'Don', 'Lake', 'M'],
#  ['269396', 'Mark Christopher', 'Lawrence', 'M'],
#  ['279903', 'Van', 'Ling', 'M'],
#  ['284866', 'Jared', 'Lounsbery', 'M'],
#  ['288301', 'Colin Patrick', 'Lynch', 'M'],
#  ['310084', 'Tom (I)', 'McDonald', 'M'],
#  ['332070', 'Joe', 'Morton', 'M'],
#  ['336379', 'Mike', 'Muscat', 'M'],
#  ['346378', 'DeVaughn', 'Nixon', 'M'],
#  ['347730', 'Dean', 'Norris', 'M'],
#  ['360529', 'Jim (I)', 'Palmer', 'M'],
#  ['374220', 'Denney', 'Pierce', 'M'],
#  ['425673', 'Peter', 'Schrum', 'M'],
#  ['433531', 'Scott (I)', 'Shaw', 'M'],
#  ['439561', 'Tony', 'Simotes', 'M'],
#  ['451689', 'Dan', 'Stanton', 'M'],
#  ['451692', 'Don', 'Stanton', 'M'],
#  ['465636', 'Charles A.', 'Tamburro', 'M'],
#  ['493307', 'Richard', 'Vidan', 'M'],
#  ['510502', 'Shane', 'Wilder', 'M'],
#  ['511606', 'Gerard G.', 'Williams', 'M'],
#  ['514131', 'Robert', 'Winley', 'M'],
#  ['522268', 'Ron (I)', 'Young', 'M'],
#  ['563244', 'Lisa', 'Brinegar', 'F'],
#  ['588077', 'Nikki', 'Cox', 'F'],
#  ['597793', 'Gwenda', 'Deacon', 'F'],
#  ['608796', "Na'loni", 'Durden', 'F'],
#  ['614721', 'Noel', 'Evangelisti', 'F'],
#  ['620255', 'Nancy', 'Fish', 'F'],
#  ['645152', 'Leslie', 'Hamilton Gearren', 'F'],
#  ['720259', 'S. Epatha', 'Merkerson', 'F'],
#  ['771500', 'Diane', 'Rodriguez', 'F'],
#  ['828805', 'Misty Jo', 'Walker', 'F'],
#  ['58045', 'John E.', 'Bristol', 'M'],
#  ['92891', 'Franco', 'Columbu', 'M'],
#  ['124873', 'Ed', 'Dogans', 'M'],
#  ['132356', 'John', 'Durban', 'M'],
#  ['145889', 'Hugh', 'Farrington', 'M'],
#  ['160251', 'Norman', 'Friedman', 'M'],
#  ['160622', 'Ken (I)', 'Fritz', 'M'],
#  ['179526', 'Philip (I)', 'Gordon', 'M'],
#  ['236878', 'Al', 'Kahn', 'M'],
#  ['245075', 'Bruce M.', 'Kerner', 'M'],
#  ['321383', 'Dick (I)', 'Miller', 'M'],
#  ['323583', 'Tony', 'Mirelez', 'M'],
#  ['331400', 'Leslie (I)', 'Morris', 'M'],
#  ['351978', 'Tom', 'Oberhaus', 'M'],
#  ['374217', 'David (II)', 'Pierce', 'M'],
#  ['375423', 'Patrick', 'Pinney', 'M'],
#  ['388681', 'James', 'Ralston', 'M'],
#  ['392215', 'Brad', 'Rearden', 'M'],
#  ['398193', 'Bill W.', 'Richmond', 'M'],
#  ['401041', 'Gregory', 'Robbins', 'M'],
#  ['408622', 'Rick', 'Rossovich', 'M'],
#  ['456639', 'Wayne', 'Stone', 'M'],
#  ['472024', 'Brian (I)', 'Thompson', 'M'],
#  ['480252', 'Anthony', 'Trujillo', 'M'],
#  ['511368', "Chino 'Fats'", 'Williams', 'M'],
#  ['512349', 'Webster', 'Williams', 'M'],
#  ['513935', 'Paul', 'Winfield', 'M'],
#  ['519450', 'Stan', 'Yale', 'M'],
#  ['624665', 'Loree', 'Frazier', 'F'],
#  ['659683', 'Hettie Lynne', 'Hurtes', 'F'],
#  ['718489', 'Harriet', 'Medin', 'F'],
#  ['730105', 'Bess', 'Motta', 'F'],
#  ['730692', 'Marianne', 'Muellerleile', 'F'],
#  ['758221', 'Barbara', 'Powers', 'F'],
#  ['783346', 'Shawn', 'Schepps', 'F'],
#  ['2898', 'Seth (I)', 'Adkins', 'M'],
#  ['11865', 'Scott G.', 'Anderson', 'M'],
#  ['12043', 'Kris', 'Andersson', 'M'],
#  ['18638', 'Richard (II)', 'Ashton', 'M'],
#  ['29603', 'Jason', 'Barry', 'M'],
#  ['54608', 'Eric', 'Braeden', 'M'],
#  ['57665', 'Paul', 'Brightwell', 'M'],
#  ['66328', 'Mike', 'Butters', 'M'],
#  ['66776', 'Chris (I)', 'Byrne', 'M'],
#  ['70744', 'Bruno', 'Campolo', 'M'],
#  ['72215', 'Mark', 'Capri', 'M'],
#  ['76228', 'Nicholas', 'Cascone', 'M'],
#  ['76443', 'Aaron James', 'Cash', 'M'],
#  ['76653', 'Marc', 'Cass', 'M'],
#  ['81499', 'Mark Lindsay', 'Chapman', 'M'],
#  ['93883', 'Brendan', 'Connolly', 'M'],
#  ['95037', 'Gregory (I)', 'Cooke', 'M'],
#  ['99597', 'Chris', 'Cragnotti', 'M'],
#  ['99941', 'Simon (I)', 'Crane', 'M'],
#  ['101233', 'David', 'Cronnelly', 'M'],
#  ['118569', 'Barry', 'Dennen', 'M'],
#  ['121758', 'Leonardo', 'DiCaprio', 'M'],
#  ['125676', 'Ron', 'Donachie', 'M'],
#  ['130426', 'Shay', 'Duffin', 'M'],
#  ['134352', 'Martin', 'East', 'M'],
#  ['138312', 'Greg (II)', 'Ellis', 'M'],
#  ['140049', 'Michael', 'Ensign', 'M'],
#  ['142962', 'Jonathan', 'Evans-Jones', 'M'],
#  ['144555', 'Anders (I)', 'Falk', 'M'],
#  ['153207', 'Edward', 'Fletcher', 'M'],
#  ['155472', 'Terry', 'Forestal', 'M'],
#  ['155930', 'Edmund Alan', 'Forsyth', 'M'],
#  ['156939', 'Bernard (I)', 'Fox', 'M'],
#  ['157096', 'Richard (I)', 'Fox', 'M'],
#  ['157680', 'Romeo', 'Francis', 'M'],
#  ['162721', 'Thomas', 'FÃ¼ri', 'M'],
#  ['165721', 'Victor', 'Garber', 'M'],
#  ['167468', 'James (IV)', 'Garrett', 'M'],
#  ['172669', 'Werner', 'Giger', 'M'],
#  ['181486', 'Richard (I)', 'Graham', 'M'],
#  ['186652', 'Ioan', 'Gruffudd', 'M'],
#  ['199768', 'Lorenz', 'Hasler', 'M'],
#  ['205287', 'Paul (IV)', 'Herbert', 'M'],
#  ['208287', 'Bernard', 'Hill', 'M'],
#  ['209729', 'Scott', 'Hislop', 'M'],
#  ['211832', 'Erik', 'Holland', 'M'],
#  ['216473', 'Martin', 'Hub', 'M'],
#  ['219643', 'Jonathan', 'Hyde', 'M'],
#  ['226351', 'Emmett', 'James', 'M'],
#  ['227836', 'Martin', 'Jarvis', 'M'],
#  ['230528', 'Rudy', 'Joffroy', 'M'],
#  ['243306', 'Craig (II)', 'Kelly', 'M'],
#  ['244575', 'Tony (I)', 'Kenny', 'M'],
#  ['248904', 'Jari (I)', 'Kinnunen', 'M'],
#  ['263645', 'Martin (I)', 'Laing', 'M'],
#  ['264813', 'James', 'Lancaster', 'M'],
#  ['270444', 'Derek', 'Lea', 'M'],
#  ['283561', 'Shep', 'Lonsdale', 'M'],
#  ['301563', 'Johnny (I)', 'Martin', 'M'],
#  ['307547', 'Stan', 'Mazin', 'M'],
#  ['313916', 'Nick', 'Meaney', 'M'],
#  ['335829', 'Patrick (IV)', 'Murphy', 'M'],
#  ['342443', 'Sean', 'Nepita', 'M'],
#  ['348858', 'Danny', 'Nucci', 'M'],
#  ['351253', 'Mike (II)', "O'Neal", 'M'],
#  ['354484', 'BjÃ¸rn (I)', 'Olsen', 'M'],
#  ['358426', 'Kevin', 'Owers', 'M'],
#  ['359448', 'Oliver', 'Page', 'M'],
#  ['360793', 'Lew', 'Palter', 'M'],
#  ['372149', 'Dan (I)', 'Pettersson', 'M'],
#  ['373241', 'Jonathan (I)', 'Phillips', 'M'],
#  ['444656', 'Stephen Wolfe', 'Smith', 'M'],
#  ['455151', 'Ewan (I)', 'Stewart', 'M'],
#  ['462918', 'BÃ©la', 'SzedlÃ¡k', 'M'],
#  ['462919', 'Ferenc', 'SzedlÃ¡k', 'M'],
#  ['468177', 'Rocky (I)', 'Taylor', 'M'],
#  ['471961', 'Reece P.', 'Thompson III', 'M'],
#  ['480062', 'R. Gern', 'Trowbridge', 'M'],
#  ['480247', 'Mark Rafael', 'Truitt', 'M'],
#  ['481840', 'Liam', 'Tuohy', 'M'],
#  ['482854', 'Stephen', 'Twigger', 'M'],
#  ['484826', 'Vern', 'Urich', 'M'],
#  ['497962', 'Francisco', 'VÃ¡ldez', 'M'],
#  ['499298', 'John', 'Walcutt', 'M'],
#  ['500666', 'Brian (II)', 'Walsh', 'M'],
#  ['502344', 'David (I)', 'Warner', 'M'],
#  ['505031', 'Stephen', 'Wehmeyer', 'M'],
#  ['513645', 'Garth', 'Wilton', 'M'],
#  ['524132', 'Billy', 'Zane', 'M'],
#  ['534915', 'Suzy', 'Amis', 'F'],
#  ['541702', 'Rosalind', 'Ayres', 'F'],
#  ['547276', 'Bobbie', 'Bates', 'F'],
#  ['547303', 'Kathy (I)', 'Bates', 'F'],
#  ['560216', 'Dawn M.', 'Bourn', 'F'],
#  ['560719', 'Alexandra', 'Boyd', 'F'],
#  ['562717', 'Fannie', 'Brett', 'F'],
#  ['578075', 'Charlotte', 'Chatton', 'F'],
#  ['608339', 'Kathleen S.', 'Dunn', 'F'],
#  ['620301', 'Frances (I)', 'Fisher', 'F'],
#  ['621016', 'Anne', 'Fletcher', 'F'],
#  ['627384', 'Amy', 'Gaipa', 'F'],
#  ['629712', 'Aimee Amanda', 'Garten', 'F'],
#  ['629713', 'Jo Lynn', 'Garten', 'F'],
#  ['653279', 'Andie', 'Hicks', 'F'],
#  ['659281', 'Samantha', 'Hunt', 'F'],
#  ['675117', 'Linda', 'Kerns', 'F'],
#  ['678541', 'Rebecca', 'Klingler', 'F'],
#  ['687048', 'Laramie', 'Landis', 'F'],
#  ['709423', 'Mandana', 'Marino', 'F'],
#  ['728576', 'Diana (II)', 'Morgan', 'F'],
#  ['740170', 'Ellen', "O'Brien", 'F'],
#  ['744930', 'Camilla', 'Overbye Roos', 'F'],
#  ['745079', 'Alexandrea', 'Owens', 'F'],
#  ['763718', 'Lisa', 'Ratzin', 'F'],
#  ['763862', 'Elsa', 'Raven', 'F'],
#  ['766230', 'Julene', 'Renee', 'F'],
#  ['773658', 'Rochelle', 'Rose', 'F'],
#  ['803835', 'Gloria', 'Stuart', 'F'],
#  ['827985', 'Alison', 'Waddell', 'F'],
#  ['827986', 'Amber', 'Waddell', 'F'],
#  ['837199', 'Kate', 'Winslet', 'F'],
#  ['4961', 'Mike', 'Akrawi', 'M'],
#  ['7991', 'James (IV)', 'Allen', 'M'],
#  ['17191', 'Tom (I)', 'Arnold', 'M'],
#  ['29743', 'Paul', 'Barselou', 'M'],
#  ['99596', 'Charles', 'Cragin', 'M'],
#  ['127182', 'Scott', 'Dotson', 'M'],
#  ['163705', 'Uzi', 'Gal', 'M'],
#  ['206867', 'Grant', 'Heslov', 'M'],
#  ['207002', 'Charlton', 'Heston', 'M'],
#  ['220569', 'Majed', 'Ibrahim', 'M'],
#  ['258898', 'Armen', 'Ksajikian', 'M'],
#  ['294609', 'Art', 'Malik', 'M'],
#  ['295961', 'Marshall', 'Manesh', 'M'],
#  ['298368', 'Louai', 'Mardini', 'M'],
#  ['346027', 'Andre', 'Nirmel', 'M'],
#  ['362022', 'Jean-Claude', 'Parachini', 'M'],
#  ['362418', 'Erik', 'Parillo', 'M'],
#  ['370282', 'Manuel', 'Perry', 'M'],
#  ['373813', 'Charlie (I)', 'Picerni', 'M'],
#  ['391197', 'Dieter', 'Rauter', 'M'],
#  ['416883', 'Gino', 'Salvano', 'M'],
#  ['417399', 'Ofer', 'Samra', 'M'],
#  ['573294', 'Tia', 'Carrere', 'F'],
#  ['577530', 'Katsy', 'Chappell', 'F'],
#  ['590629', 'Jamie Lee', 'Curtis', 'F'],
#  ['598141', 'Mary A.', 'DeBriae', 'F'],
#  ['608999', 'Eliza', 'Dushku', 'F'],
#  ['729268', 'Jane (I)', 'Morris', 'F'],
#  ['839732', 'Crystina', 'Wyler', 'F'],
#  ['819133', 'Margaret', 'Undiel', 'F'],
#  ['10651', 'Martin', 'Amor', 'M'],
#  ['18544', 'John (III)', 'Ashley', 'M'],
#  ['33046', 'Robert (I)', 'Beatty', 'M'],
#  ['33492', 'Glenn', 'Beck', 'M'],
#  ['35269', 'Jimmy', 'Bell', 'M'],
#  ['43766', 'Ed (I)', 'Bishop', 'M'],
#  ['81735', 'David', 'Charkham', 'M'],
#  ['89366', 'John (I)', 'Clifford', 'M'],
#  ['110691', 'Simon (I)', 'Davis', 'M'],
#  ['110901', 'Jonathan', 'Daw', 'M'],
#  ['117597', 'PÃ©ter', 'DelmÃ¡r', 'M'],
#  ['130668', 'Terry (I)', 'Duggan', 'M'],
#  ['130919', 'Keir', 'Dullea', 'M'],
#  ['152930', 'David (II)', 'Fleetwood', 'M'],
#  ['172616', 'Alan', 'Gifford', 'M'],
#  ['186410', 'Danny', 'Grover', 'M'],
#  ['200989', 'Brian (I)', 'Hawley', 'M'],
#  ['209041', 'David (I)', 'Hines', 'M'],
#  ['225060', 'Tony (I)', 'Jackson', 'M'],
#  ['234019', 'John (X)', 'Jordan', 'M'],
#  ['244025', 'Kenneth', 'Kendall', 'M'],
#  ['282170', 'Gary', 'Lockwood', 'M'],
#  ['285138', 'Mike', 'Lovell', 'M'],
#  ['290958', 'Scott', 'MacKee', 'M'],
#  ['297912', 'Laurence', 'Marchant', 'M'],
#  ['321439', 'Frank (I)', 'Miller', 'M'],
#  ['359269', 'Darryl', 'Paes', 'M'],
#  ['388177', 'Douglas', 'Rain', 'M'],
#  ['393452', 'Joe', 'Refalo', 'M'],
#  ['398261', 'Daniel (I)', 'Richter', 'M'],
#  ['408577', 'Leonard', 'Rossiter', 'M'],
#  ['427619', 'Kevin (I)', 'Scott', 'M'],
#  ['459935', 'Sean (I)', 'Sullivan', 'M'],
#  ['462236', 'John', 'Swindells', 'M'],
#  ['462532', 'William', 'Sylvester', 'M'],
#  ['481290', 'Burnell', 'Tucker', 'M'],
#  ['500110', 'Andy (I)', 'Wallace', 'M'],
#  ['507612', 'Bill (I)', 'Weston', 'M'],
#  ['513676', 'Bob', 'Wilyman', 'M'],
#  ['517018', 'Richard (II)', 'Woods', 'M'],
#  ['556737', 'Sheraton', 'Blount', 'F'],
#  ['559266', 'Ann', 'Bormann', 'F'],
#  ['561464', 'Penny', 'Brahms', 'F'],
#  ['573464', 'Edwina', 'Carroll', 'F'],
#  ['589087', 'Julie', 'Croft', 'F'],
#  ['606054', 'Heather', 'Downham', 'F'],
#  ['623949', 'Penny', 'Francis', 'F'],
#  ['633066', 'Ann (I)', 'Gillis', 'F'],
#  ['649736', 'Jane', 'Hayward', 'F'],
#  ['683135', 'Vivian', 'Kubrick', 'F'],
#  ['709642', 'Marcella', 'Markham', 'F'],
#  ['710214', 'Krystyna', 'Marr', 'F'],
#  ['735076', 'Kim', 'Neil', 'F'],
#  ['750078', 'Jane', 'Pearl', 'F'],
#  ['750089', 'Penny', 'Pearl', 'F'],
#  ['818459', 'Margaret', 'Tyzack', 'F'],
#  ['39086', 'Steven', 'Berkoff', 'M'],
#  ['43127', 'John', 'Bindon', 'M'],
#  ['50074', 'Roger', 'Booth', 'M'],
#  ['53692', 'Billy', 'Boyle', 'M'],
#  ['78776', 'Jonathan', 'Cecil', 'M'],
#  ['79048', 'Peter', 'Cellier', 'M'],
#  ['82337', 'Geoffrey', 'Chater', 'M'],
#  ['110921', 'Anthony', 'Dawes', 'M'],
#  ['111031', 'Patrick', 'Dawson', 'M'],
#  ['205176', 'Bernard', 'Hepton', 'M'],
#  ['206431', 'Anthony', 'Herrick', 'M'],
#  ['213908', 'Michael', 'Hordern', 'M'],
#  ['224581', 'Barry (I)', 'Jackson', 'M'],
#  ['236863', 'Wolf', 'Kahler', 'M'],
#  ['258862', 'Hardy', 'KrÃ¼ger', 'M'],
#  ['263045', 'Patrick', 'Laffan', 'M'],
#  ['292390', 'Patrick (I)', 'Magee', 'M'],
#  ['307261', 'Ferdy', 'Mayne', 'M'],
#  ['315871', 'Murray', 'Melvin', 'M'],
#  ['318503', 'Hans (I)', 'Meyer', 'M'],
#  ['319779', 'Frank', 'Middlemass', 'M'],
#  ['329794', 'AndrÃ©', 'Morell', 'M'],
#  ['330937', 'David', 'Morley', 'M'],
#  ['351264', 'Ryan', "O'Neal", 'M'],
#  ['351681', 'Arthur', "O'Sullivan", 'M'],
#  ['386178', 'Godfrey', 'Quigley', 'M'],
#  ['392783', 'Liam', 'Redmond', 'M'],
#  ['400860', 'Pat', 'Roach', 'M'],
#  ['421372', 'Dominic', 'Savage', 'M'],
#  ['423761', 'Frederick', 'Schiller', 'M'],
#  ['431642', 'George', 'Sewell', 'M'],
#  ['433046', 'Anthony', 'Sharp', 'M'],
#  ['433086', 'John (I)', 'Sharp', 'M'],
#  ['449193', 'Roy', 'Spencer', 'M'],
#  ['456570', 'Philip (I)', 'Stone', 'M'],
#  ['459849', 'John (I)', 'Sullivan', 'M'],
#  ['467844', 'Gary (II)', 'Taylor', 'M'],
#  ['477807', 'Harry', 'Towb', 'M'],
#  ['495397', 'Leon', 'Vitali', 'M'],
#  ['551488', 'Marisa', 'Berenson', 'F'],
#  ['645202', 'Gay', 'Hamilton', 'F'],
#  ['673249', 'Marie', 'Kean', 'F'],
#  ['684623', 'Diana', 'KÃ¶rner', 'F'],
#  ['31234', 'Michael (I)', 'Bates', 'M'],
#  ['65405', 'Peter', 'Burton', 'M'],
#  ['70489', 'Lindsay (I)', 'Campbell', 'M'],
#  ['73946', 'John J.', 'Carney', 'M'],
#  ['88544', 'Warren', 'Clarke', 'M'],
#  ['89519', 'John', 'Clive', 'M'],
#  ['93696', 'Richard', 'Connaught', 'M'],
#  ['95089', 'Barrie', 'Cookson', 'M'],
#  ['130329', 'Carl', 'Duering', 'M'],
#  ['145816', 'Paul (I)', 'Farrell', 'M'],
#  ['157057', 'Lee', 'Fox', 'M'],
#  ['157573', 'Clive', 'Francis', 'M'],
#  ['180761', 'Michael', 'Gover', 'M'],
#  ['208928', 'Heinrich', 'Himmler', 'M'],
#  ['209799', 'Adolf', 'Hitler', 'M'],
#  ['218405', 'Craig (I)', 'Hunter', 'M'],
#  ['287974', 'Viktor', 'Lutze', 'M'],
#  ['298288', 'James (II)', 'Marcus', 'M'],
#  ['310213', 'Malcolm', 'McDowell', 'M'],
#  ['331189', 'Aubrey', 'Morris', 'M'],
#  ['350799', 'George', "O'Gorman", 'M'],
#  ['383596', 'David', 'Prowse', 'M'],
#  ['421615', 'John', 'Savident', 'M'],
#  ['466779', 'Michael', 'Tarn', 'M'],
#  ['513394', 'Neil (I)', 'Wilson', 'M'],
#  ['529804', 'Jan', 'Adair', 'F'],
#  ['564580', 'Gaye', 'Brown', 'F'],
#  ['577143', 'Vivienne', 'Chandler', 'F'],
#  ['586737', 'Adrienne', 'Corri', 'F'],
#  ['606245', 'Prudence', 'Drage', 'F'],
#  ['606720', 'Carol', 'Drinkwater', 'F'],
#  ['640907', 'Cheryl', 'Grunwald', 'F'],
#  ['654069', 'Gillian', 'Hills', 'F'],
#  ['663573', 'Shirley', 'Jaffe', 'F'],
#  ['671758', 'Miriam', 'Karlin', 'F'],
#  ['764299', 'Sheila', 'Raynor', 'F'],
#  ['777198', 'Madge', 'Ryan', 'F'],
#  ['785548', 'Barbara (V)', 'Scott', 'F'],
#  ['809779', 'Pauline (I)', 'Taylor', 'F'],
#  ['833428', 'Virginia', 'Wetherell', 'F'],
#  ['839709', 'Katya', 'Wyeth', 'F'],
#  ['75587', 'Vincent', 'Cartier', 'M'],
#  ['75588', 'Walter', 'Cartier', 'M'],
#  ['135670', 'Douglas (I)', 'Edwards', 'M'],
#  ['152958', 'Nate', 'Fleischer', 'M'],
#  ['226249', 'Bobby (II)', 'James', 'M'],
#  ['259066', 'Stanley', 'Kubrick', 'M'],
#  ['440126', 'Alexander', 'Singer', 'M'],
#  ['792995', 'Judy (I)', 'Singer', 'F'],
#  ['40172', 'Frank (I)', 'Berry', 'M'],
#  ['63409', 'Peter (I)', 'Bull', 'M'],
#  ['100404', 'Jack', 'Creley', 'M'],
#  ['164035', 'Hal', 'Galili', 'M'],
#  ['201256', 'Sterling', 'Hayden', 'M'],
#  ['205401', 'Laurence', 'Herder', 'M'],
#  ['233082', 'James Earl', 'Jones', 'M'],
#  ['308556', 'John (I)', 'McCarthy', 'M'],
#  ['351321', 'Robert (I)', "O'Neil", 'M'],
#  ['373935', 'Slim (I)', 'Pickens', 'M'],
#  ['399367', 'Shane', 'Rimmer', 'M'],
#  ['427460', 'George C.', 'Scott', 'M'],
#  ['429719', 'Peter', 'Sellers', 'M'],
#  ['453983', 'Roy', 'Stephens', 'M'],
#  ['465553', 'Paul', 'Tamarin', 'M'],
#  ['466257', 'Gordon (II)', 'Tanner', 'M'],
#  ['518686', 'Keenan', 'Wynn', 'M'],
#  ['764987', 'Tracy (II)', 'Reed', 'F'],
#  ['13279', 'Colin', 'Angus', 'M'],
#  ['37627', 'Peter (III)', 'Benson', 'M'],
#  ['88365', 'Christian (II)', 'Clarke', 'M'],
#  ['93702', 'Kevin', 'Connealy', 'M'],
#  ['94781', 'Brian W.', 'Cook', 'M'],
#  ['101879', 'Tom', 'Cruise', 'M'],
#  ['102958', 'Alan', 'Cumming', 'M'],
#  ['104692', 'Emilio', "D'Alessandro", 'M'],
#  ['109877', 'Phil (IV)', 'Davies', 'M'],
#  ['114088', 'Ben', 'De Saumserez', 'M'],
#  ['117903', 'James', 'Demaria', 'M'],
#  ['119566', 'Anthony', 'Desergio', 'M'],
#  ['127583', 'Sam (I)', 'Douglas', 'M'],
#  ['127777', 'Michael', 'Doven', 'M'],
#  ['131110', 'Sky', 'Dumont', 'M'],
#  ['142332', 'Treva', 'Etienne', 'M'],
#  ['149979', 'Todd', 'Field', 'M'],
#  ['172461', 'Thomas (I)', 'Gibson', 'M'],
#  ['175890', 'Gary', 'Goba', 'M'],
#  ['176266', 'Peter (I)', 'Godwin', 'M'],
#  ['205014', 'Lee', 'Henshaw', 'M'],
#  ['210176', 'Alex', 'Hobbs', 'M'],
#  ['220892', 'Togo', 'Igawa', 'M'],
#  ['260733', 'Eiji', 'Kusuhara', 'M'],
#  ['277792', 'Adam', 'Lias', 'M'],
#  ['290708', 'Angus', 'MacInnes', 'M'],
#  ['362250', 'Chris', 'Pare', 'M'],
#  ['365531', 'Randall', 'Paul', 'M'],
#  ['370217', 'Gavin', 'Perry', 'M'],
#  ['378271', 'Sydney', 'Pollack', 'M'],
#  ['384073', 'Adam', 'Pudney', 'M'],
#  ['405530', 'Dan', 'Rollman', 'M'],
#  ['430641', 'Rade', 'Serbedzija', 'M'],
#  ['448978', 'Paul', 'Spelling', 'M'],
#  ['472331', 'Matthew (II)', 'Thompson', 'M'],
#  ['478574', 'Dan', 'Travers', 'M'],
#  ['479388', 'Russell', 'Trigg', 'M'],
#  ['508334', 'Kyle', 'Whitcombe', 'M'],
#  ['513864', 'Florian', 'Windorfer', 'M'],
#  ['539877', 'Karla', 'Ashley', 'F'],
#  ['573883', 'Heather', 'Carter-Drake', 'F'],
#  ['577756', 'Kathryn', 'Charman', 'F'],
#  ['594783', 'Julienne', 'Davis', 'F'],
#  ['602507', 'Janie', 'Dickens', 'F'],
#  ['604337', 'Cindy', 'Dolenc', 'F'],
#  ['611037', 'Madison', 'Eginton', 'F'],
#  ['615217', 'Donna', 'Ewin', 'F'],
#  ['616025', 'Laura', 'Fallace', 'F'],
#  ['617848', 'Vanessa (II)', 'Fenton', 'F'],
#  ['619666', 'Georgina', 'Finch', 'F'],
#  ['635912', 'Abigail', 'Good', 'F'],
#  ['645973', 'Tres', 'Hanley', 'F'],
#  ['649487', 'Clark (I)', 'Hayes', 'F'],
#  ['650090', 'Joanna', 'Heath', 'F'],
#  ['653067', 'Mariana', 'Hewett', 'F'],
#  ['675927', 'Nicole', 'Kidman', 'F'],
#  ['683132', 'Christiane', 'Kubrick', 'F'],
#  ['683134', 'Katharina', 'Kubrick', 'F'],
#  ['693690', 'Lisa (I)', 'Leone', 'F'],
#  ['700691', 'Leslie', 'Lowe', 'F'],
#  ['709994', 'Carmela', 'Marner', 'F'],
#  ['712865', 'Fay', 'Masterson', 'F'],
#  ['757084', 'Ateeka', 'Poole', 'F'],
#  ['761200', 'Sharon', 'Quinn', 'F'],
#  ['768088', 'Marie', 'Richardson', 'F'],
#  ['782497', 'Jackie', 'Sawiris', 'F'],
#  ['788960', 'Emma Lou', 'Sharratt', 'F'],
#  ['789192', 'Vinessa', 'Shaw', 'F'],
#  ['796007', 'Leelee', 'Sobieski', 'F'],
#  ['809699', 'Louise J.', 'Taylor', 'F'],
#  ['812607', 'Stewart', 'Thorndike', 'F'],
#  ['833537', 'Kate', 'Whalin', 'F'],
#  ['7872', 'David (IX)', 'Allen', 'M'],
#  ['91059', 'Stephen', 'Coit', 'M'],
#  ['197444', 'Kenneth', 'Harp', 'M'],
#  ['307631', 'Paul', 'Mazursky', 'M'],
#  ['438416', 'Frank', 'Silvera', 'M'],
#  ['692929', 'Virginia', 'Leith', 'F'],
#  ['209787', 'Bob (II)', 'Hite', 'M'],
#  ['450798', 'Fred', 'Stadmueller', 'M'],
#  ['2397', 'Martin (I)', 'Adams', 'M'],
#  ['5871', 'Kevin', 'Albridge', 'M'],
#  ['11483', 'Del', 'Anderson', 'M'],
#  ['23587', 'Philip', 'Bailey', 'M'],
#  ['25000', 'Adam', 'Baldwin', 'M'],
#  ['28036', 'Louis', 'Barlotti', 'M'],
#  ['33920', 'John', 'Beddows', 'M'],
#  ['37048', 'Patrick', 'Benn', 'M'],
#  ['46980', 'Bruce', 'Boa', 'M'],
#  ['51909', 'Steve', 'Boucher', 'M'],
#  ['65610', 'Adrian', 'Bush', 'M'],
#  ['73009', 'Tony (II)', 'Carey', 'M'],
#  ['82885', 'Gary', 'Cheeseman', 'M'],
#  ['84498', 'Costas Dino', 'Chimona', 'M'],
#  ['88311', 'Wayne (I)', 'Clark', 'M'],
#  ['91262', 'Tim', 'Colceri', 'M'],
#  ['96626', 'Chris', 'Cornibert', 'M'],
#  ['96627', 'Danny', 'Cornibert', 'M'],
#  ['103836', 'John (II)', 'Curtis', 'M'],
#  ['104783', 'Marcus', "D'Amico", 'M'],
#  ['105163', 'Vincent (I)', "D'Onofrio", 'M'],
#  ['109795', 'Harry (II)', 'Davies', 'M'],
#  ['110386', 'John (IV)', 'Davis', 'M'],
#  ['111143', 'Kevin (II)', 'Day', 'M'],
#  ['131274', 'Gordon', 'Duncan', 'M'],
#  ['135439', 'Peter', 'Edmund', 'M'],
#  ['138603', 'Phil', 'Elmer', 'M'],
#  ['138841', 'Colin', 'Elvis', 'M'],
#  ['140869', 'R. Lee', 'Ermey', 'M'],
#  ['154493', 'Hadrian', 'Follett', 'M'],
#  ['157531', 'Tan Hung', 'Francione', 'M'],
#  ['158116', 'Sean', 'Frank', 'M'],
#  ['170357', 'David (I)', 'George', 'M'],
#  ['178992', 'Brian', 'Goodwin', 'M'],
#  ['180610', 'Nigel', 'Goulding', 'M'],
#  ['192157', 'Tony', 'Hague', 'M'],
#  ['195193', 'Steve', 'Hands', 'M'],
#  ['196997', 'Dorian', 'Harewood', 'M'],
#  ['197859', 'Chris (I)', 'Harris', 'M'],
#  ['198687', 'Bob (II)', 'Hart', 'M'],
#  ['198727', 'Derek (II)', 'Hart', 'M'],
#  ['201301', 'Barry', 'Hayes', 'M'],
#  ['201490', 'Tony (II)', 'Hayes', 'M'],
#  ['201936', 'Kenneth', 'Head', 'M'],
#  ['202517', 'Robin', 'Hedgeland', 'M'],
#  ['204833', 'Duncan', 'Henry', 'M'],
#  ['210579', 'Keith', 'Hodiak', 'M'],
#  ['211209', 'Liam', 'Hogan', 'M'],
#  ['211245', 'Trevor', 'Hogan', 'M'],
#  ['211261', 'Luke', 'Hogdal', 'M'],
#  ['215357', 'Arliss', 'Howard', 'M'],
#  ['215534', 'Kevyn Major', 'Howard', 'M'],
#  ['215643', 'Tony', 'Howard', 'M'],
#  ['216936', 'Steve (II)', 'Hudson', 'M'],
#  ['228364', 'Kieron', 'Jecchinis', 'M'],
#  ['254447', 'Gil', 'Kopel', 'M'],
#  ['264558', 'Sean', 'Lamming', 'M'],
#  ['265128', 'Dan (I)', 'Landin', 'M'],
#  ['272581', 'Tony', 'Leete', 'M'],
#  ['283927', 'Sal', 'Lopez', 'M'],
#  ['284721', 'Nigel', 'Lough', 'M'],
#  ['285408', 'Terry (I)', 'Lowe', 'M'],
#  ['307000', 'Chris', 'Maybach', 'M'],
#  ['308458', 'Frank', 'McCardle', 'M'],
#  ['317493', 'Peter', 'Merrill', 'M'],
#  ['318493', 'Gary (I)', 'Meyer', 'M'],
#  ['319786', 'Brett', 'Middleton', 'M'],
#  ['322263', 'Gary Landon', 'Mills', 'M'],
#  ['322448', 'David (I)', 'Milner', 'M'],
#  ['323110', 'Sean', 'Minmagh', 'M'],
#  ['323111', 'Tony', 'Minmagh', 'M'],
#  ['325263', 'Matthew', 'Modine', 'M'],
#  ['331636', 'John (VIII)', 'Morrison', 'M'],
#  ['332927', 'Russell', 'Mott', 'M'],
#  ['342634', 'John', 'Ness', 'M'],
#  ['344407', 'Robert (V)', 'Nichols', 'M'],
#  ['348031', 'Herbert', 'Norville', 'M'],
#  ['351565', 'Ed', "O'Ross", 'M'],
#  ['360186', 'David', 'Palffy', 'M'],
#  ['370184', 'David (I)', 'Perry', 'M'],
#  ['373513', 'Nguyen Hue', 'Phong', 'M'],
#  ['406269', 'Peter', 'Rommely', 'M'],
#  ['418550', 'Pat', 'Sands', 'M'],
#  ['420532', 'Jim', 'Sarup', 'M'],
#  ['439592', 'Al (I)', 'Simpson', 'M'],
#  ['442258', 'Russell', 'Slater', 'M'],
#  ['443772', 'Gary (I)', 'Smith', 'M'],
#  ['444548', 'Roger (VI)', 'Smith', 'M'],
#  ['444747', 'Tony (II)', 'Smith', 'M'],
#  ['450874', 'Jon', 'Stafford', 'M'],
#  ['458996', 'Anthony', 'Styliano', 'M'],
#  ['464072', 'Duc Hu', 'Ta', 'M'],
#  ['468001', 'Kirk', 'Taylor', 'M'],
#  ['469867', 'John (I)', 'Terry', 'M'],
#  ['472006', 'Bill (IV)', 'Thompson', 'M'],
#  ['482081', 'Mike', 'Turjansky', 'M'],
#  ['482993', 'Ian', 'Tyler', 'M'],
#  ['506029', 'Dan (I)', 'Weldon', 'M'],
#  ['506265', 'Dennis', 'Wells', 'M'],
#  ['511949', 'Michael (III)', 'Williams', 'M'],
#  ['513249', 'John (V)', 'Wilson', 'M'],
#  ['515954', 'John', 'Wonderling', 'M'],
#  ['635367', 'Laurie', 'Gomes', 'F'],
#  ['656446', 'Leanne', 'Hong', 'F'],
#  ['690482', 'Ngoc', 'Le', 'F'],
#  ['796984', 'Papillon', 'Soo', 'F'],
#  ['2753', 'Skippy', 'Adelman', 'M'],
#  ['107156', 'Mike (I)', 'Dana', 'M'],
#  ['147229', 'Arthur', 'Feldman', 'M'],
#  ['162007', 'Bill', 'Funaro', 'M'],
#  ['227733', 'Jerry', 'Jarret', 'M'],
#  ['350108', 'Shaun', "O'Brien", 'M'],
#  ['355874', 'Felice', 'Orlandi', 'M'],
#  ['401685', 'Ralph (I)', 'Roberts', 'M'],
#  ['410475', 'Alec', 'Rubin', 'M'],
#  ['443960', 'Jamie (I)', 'Smith', 'M'],
#  ['454948', 'Phil', 'Stevenson', 'M'],
#  ['490228', 'David (I)', 'Vaughan', 'M'],
#  ['561594', 'Barbara', 'Brand', 'F'],
#  ['670943', 'Irene', 'Kane', 'F'],
#  ['796029', 'Ruth', 'Sobotka', 'F'],
#  ['2949', 'Jay', 'Adler', 'M'],
#  ['36662', "William 'Billy'", 'Benedict', 'M'],
#  ['71122', 'Charles', 'Cane', 'M'],
#  ['73002', 'Timothy', 'Carey', 'M'],
#  ['94748', 'Elisha', 'Cook Jr.', 'M'],
#  ['112053', 'Ted', 'de Corsia', 'M'],
#  ['135744', 'James (I)', 'Edwards', 'M'],
#  ['135921', 'Vince', 'Edwards', 'M'],
#  ['138317', 'Herbert (I)', 'Ellis', 'M'],
#  ['153433', 'Jay C.', 'Flippen', 'M'],
#  ['173683', 'Art', 'Gilmore', 'M'],
#  ['179947', 'Sol', 'Gorss', 'M'],
#  ['185181', 'James (I)', 'Griffith', 'M'],
#  ['261145', 'Kola', 'Kwariani', 'M'],
#  ['324376', 'Steve (I)', 'Mitchell', 'M'],
#  ['328560', 'Hal J.', 'Moore', 'M'],
#  ['393428', 'Richard (I)', 'Reeves', 'M'],
#  ['397677', 'Frank (I)', 'Richards', 'M'],
#  ['421893', 'Joe', 'Sawyer', 'M'],
#  ['482105', 'Joe', 'Turkel', 'M'],
#  ['497834', 'Tito', 'Vuolo', 'M'],
#  ['512106', 'Robert (I)', 'Williams', 'M'],
#  ['530012', 'Dorothy', 'Adams', 'F'],
#  ['573511', 'Mary (I)', 'Carroll', 'F'],
#  ['612055', 'Cecil', 'Elliott', 'F'],
#  ['638426', 'Coleen', 'Gray', 'F'],
#  ['836963', 'Marie', 'Windsor', 'F'],
#  ['7976', 'Irvin', 'Allen', 'M'],
#  ['55062', 'Roland', 'Brand', 'M'],
#  ['90262', 'Gary', 'Cockrell', 'M'],
#  ['103985', 'Peter', 'Cushing', 'M'],
#  ['133423', 'James (I)', 'Dyrenforth', 'M'],
#  ['183776', 'Bill (I)', 'Greene', 'M'],
#  ['198438', 'John (VII)', 'Harrison', 'M'],
#  ['247182', 'Terry', 'Kilburn', 'M'],
#  ['265390', 'Eric (I)', 'Lane', 'M'],
#  ['271543', 'Christopher (I)', 'Lee', 'M'],
#  ['279385', 'Cec', 'Linder', 'M'],
#  ['293607', 'Colin', 'Maitland', 'M'],
#  ['303906', 'James (I)', 'Mason', 'M'],
#  ['358119', 'Robert C.', 'Overton', 'M'],
#  ['417404', 'Craig', 'Sams', 'M'],
#  ['457044', 'Jerry', 'Stovin', 'M'],
#  ['502490', 'C. Denier', 'Warren', 'M'],
#  ['598240', 'Diana', 'Decker', 'F'],
#  ['605798', 'Shirley', 'Douglas', 'F'],
#  ['632299', 'Susanne', 'Gibbs', 'F'],
#  ['655488', 'Maxine', 'Holden', 'F'],
#  ['701079', 'Isabelle', 'Lucas', 'F'],
#  ['702877', 'Sue', 'Lyon', 'F'],
#  ['713189', 'Marion', 'Mathie', 'F'],
#  ['714240', 'Lois', 'Maxwell', 'F'],
#  ['790816', 'Roberta', 'Shore', 'F'],
#  ['802676', 'Marianne', 'Stone', 'F'],
#  ['837410', 'Shelley', 'Winters', 'F'],
#  ['11822', 'Richard (I)', 'Anderson', 'M'],
#  ['35214', 'Fred', 'Bell', 'M'],
#  ['36638', 'Harold', 'Benedict', 'M'],
#  ['57565', 'Leon', 'Briggs', 'M'],
#  ['67337', 'Paul', 'BÃ¶s', 'M'],
#  ['71871', 'Peter', 'Capell', 'M'],
#  ['121723', 'Kem', 'Dibbs', 'M'],
#  ['127515', 'Kirk (I)', 'Douglas', 'M'],
#  ['159149', 'Bert', 'Freed', 'M'],
#  ['160330', 'Wally', 'Friedrichs', 'M'],
#  ['196132', 'Halder', 'Hanson', 'M'],
#  ['198005', 'James B.', 'Harris', 'M'],
#  ['200578', 'Jerry', 'Hausner', 'M'],
#  ['256772', 'Rolf', 'Kralovitz', 'M'],
#  ['291501', 'George', 'Macready', 'M'],
#  ['314498', 'Ralph', 'Meeker', 'M'],
#  ['316559', 'Adolphe', 'Menjou', 'M'],
#  ['318477', 'Emile', 'Meyer', 'M'],
#  ['328569', 'Ira', 'Moore', 'M'],
#  ['331537', 'Wayne (I)', 'Morris', 'M'],
#  ['388222', 'Marshall', 'Rainer', 'M'],
#  ['453199', 'John (I)', 'Stein', 'M'],
#  ['485541', 'Roger', 'Vagnoid', 'M'],
#  ['211966', 'Dan', 'Hollenbeck', 'M'],
#  ['32161', 'David', 'Baxt', 'M'],
#  ['65437', 'Tony (I)', 'Burton', 'M'],
#  ['101532', 'Scatman', 'Crothers', 'M'],
#  ['168964', 'Norman', 'Gay', 'M'],
#  ['281601', 'Danny', 'Lloyd', 'M'],
#  ['341935', 'Barry (I)', 'Nelson', 'M'],
#  ['344454', 'Jack', 'Nicholson', 'M'],
#  ['392853', 'Manning', 'Redwood', 'M'],
#  ['549455', 'Lia', 'Beldam', 'F'],
#  ['567465', 'Lisa (I)', 'Burns', 'F'],
#  ['567466', 'Louise (I)', 'Burns', 'F'],
#  ['583685', 'Alison', 'Coleridge', 'F'],
#  ['609183', 'Shelley', 'Duvall', 'F'],
#  ['632333', 'Billie', 'Gibson', 'F'],
#  ['662905', 'Anne', 'Jackson', 'F'],
#  ['747261', 'Robin', 'Pappas', 'F'],
#  ['753642', 'Kate', 'Phelps', 'F'],
#  ['789514', 'Jana', 'Sheldon', 'F'],
#  ['31073', 'Arthur', 'Batanides', 'M'],
#  ['44648', 'Bill (II)', 'Blackburn', 'M'],
#  ['54507', 'Buff', 'Brady', 'M'],
#  ['58391', 'Peter', 'Brocco', 'M'],
#  ['63265', 'Rudy', 'Bukich', 'M'],
#  ['64809', 'Bob (VII)', 'Burns', 'M'],
#  ['64945', 'Paul E.', 'Burns', 'M'],
#  ['71744', 'Joe', 'Canutt', 'M'],
#  ['71745', 'Tap', 'Canutt', 'M'],
#  ['73734', 'Al', 'Carmichael', 'M'],
#  ['98633', 'Chuck', 'Courtney', 'M'],
#  ['100988', 'Dick', 'Crockett', 'M'],
#  ['103906', 'Tony (I)', 'Curtis', 'M'],
#  ['106501', 'John', 'Dall', 'M'],
#  ['113277', 'Terence', 'de Marney', 'M'],
#  ['118675', 'Nick', 'Dennis', 'M'],
#  ['131290', 'Johnny', 'Duncan', 'M'],
#  ['139557', 'Roy', 'Engel', 'M'],
#  ['145612', 'Richard', 'Farnsworth', 'M'],
#  ['168813', 'John (I)', 'Gavin', 'M'],
#  ['175059', 'Seamon', 'Glass', 'M'],
#  ['179004', 'Harold (I)', 'Goodwin', 'M'],
#  ['199295', 'Harry', 'Harvey Jr.', 'M'],
#  ['201016', 'Joe', 'Haworth', 'M'],
#  ['201022', 'Vinton', 'Haworth', 'M'],
#  ['201721', 'Chuck (I)', 'Hayward', 'M'],
#  ['214562', 'Charles', 'Horvath', 'M'],
#  ['216081', 'John (I)', 'Hoyt', 'M'],
#  ['222590', 'John (I)', 'Ireland', 'M'],
#  ['248067', 'Aron', 'Kincaid', 'M'],
#  ['258492', 'Stubby', 'Kruger', 'M'],
#  ['264368', 'Paul (I)', 'Lambert', 'M'],
#  ['268316', 'Charles', 'Laughton', 'M'],
#  ['282409', 'Carey', 'Loftin', 'M'],
#  ['282811', 'Herbert', 'Lom', 'M'],
#  ['287067', 'Dayton', 'Lummis', 'M'],
#  ['288617', 'Cliff', 'Lyons', 'M'],
#  ['311083', 'Charles', 'McGraw', 'M'],
#  ['324189', 'Gordon (I)', 'Mitchell', 'M'],
#  ['330244', 'Bob (I)', 'Morgan', 'M'],
#  ['330245', "Boyd 'Red'", 'Morgan', 'M'],
#  ['354242', 'Laurence', 'Olivier', 'M'],
#  ['362896', 'Eddie (I)', 'Parker', 'M'],
#  ['363632', 'Harvey', 'Parry', 'M'],
#  ['363813', 'Regis', 'Parton', 'M'],
#  ['368411', 'Leonard', 'Penn', 'M'],
#  ['369626', 'Gil', 'Perkins', 'M'],
#  ['370058', 'Vic', 'Perrin', 'M'],
#  ['388308', 'Bill', 'Raisch', 'M'],
#  ['401160', 'Chuck', 'Roberson', 'M'],
#  ['402707', 'George', 'Robotham', 'M'],
#  ['421223', 'Russell (II)', 'Saunders', 'M'],
#  ['422745', 'Charles (I)', 'Schaeffer', 'M'],
#  ['428306', 'Jim', 'Sears', 'M'],
#  ['452742', 'Tom (I)', 'Steele', 'M'],
#  ['454955', 'Robert (II)', 'Stevenson', 'M'],
#  ['456479', 'Harold (I)', 'Stone', 'M'],
#  ['458043', 'Woody', 'Strode', 'M'],
#  ['469772', 'Ken', 'Terrell', 'M'],
#  ['485123', 'Peter', 'Ustinov', 'M'],
#  ['488449', 'Dale', 'Van Sickel', 'M'],
#  ['510708', 'Robert J.', 'Wilke', 'M'],
#  ['517411', 'Frederick', 'Worlock', 'M'],
#  ['521921', 'Carleton', 'Young', 'M'],
#  ['545547', 'Joanna', 'Barnes', 'F'],
#  ['621646', 'Nina', 'Foch', 'F'],
#  ['653783', 'Hallene', 'Hill', 'F'],
#  ['664711', 'Jil', 'Jarmyn', 'F'],
#  ['673529', 'Valley', 'Keene', 'F'],
#  ['776584', 'Autumn', 'Russell', 'F'],
#  ['792255', 'Jean (I)', 'Simmons', 'F'],
#  ['804889', 'Jo', 'Summers', 'F'],
#  ['825612', 'Louise', 'Vincent', 'F'],
#  ['26023', 'Antonio', 'Banderas', 'M'],
#  ['36472', 'Lawrence', 'Bender', 'M'],
#  ['68754', 'Paul', 'Calderon', 'M'],
#  ['243102', 'Quinn Thomas', 'Kellerman', 'M'],
#  ['269386', 'Marc (I)', 'Lawrence', 'M'],
#  ['383529', 'David', 'Proval', 'M'],
#  ['408902', 'Tim', 'Roth', 'M'],
#  ['441448', 'Paul', 'Skemp', 'M'],
#  ['466585', 'Quentin', 'Tarantino', 'M'],
#  ['491878', 'Danny', 'Verduzco', 'M'],
#  ['497371', 'Russell', 'Vossler', 'M'],
#  ['512541', 'Bruce', 'Willis', 'M'],
#  ['548183', 'Jennifer (I)', 'Beals', 'F'],
#  ['594964', 'Sammi (I)', 'Davis', 'F'],
#  ['595847', 'Amanda', 'De Cadenet', 'F'],
#  ['635230', 'Valeria', 'Golino', 'F'],
#  ['639885', 'Kathy', 'Griffin', 'F'],
#  ['649455', 'Salma', 'Hayek', 'F'],
#  ['704821', 'Rikee', 'Madoff', 'F'],
#  ['715590', 'Unruly Julie', 'McClean', 'F'],
#  ['717432', 'Lana', 'McKissack', 'F'],
#  ['776475', 'Laura (I)', 'Rush', 'F'],
#  ['794051', 'Ione', 'Skye', 'F'],
#  ['809683', 'Lili', 'Taylor', 'F'],
#  ['814398', 'Marisa', 'Tomei', 'F'],
#  ['814439', 'Tamlyn', 'Tomita', 'F'],
#  ['827280', 'Patricia', 'Vonne', 'F'],
#  ['837678', 'Alicia', 'Witt', 'F'],
#  ['292028', 'Michael (I)', 'Madsen', 'M'],
#  ['52978', 'Michael (I)', 'Bowen', 'M'],
#  ['113561', 'Robert', 'De Niro', 'M'],
#  ['115670', 'Jeffrey', 'Deedrick', 'M'],
#  ['155904', 'Robert (I)', 'Forster', 'M'],
#  ['192290', 'Sid', 'Haig', 'M'],
#  ['225014', 'Samuel L.', 'Jackson', 'M'],
#  ['242194', 'Michael', 'Keaton', 'M'],
#  ['280645', "Tom 'Tiny'", 'Lister Jr.', 'M'],
#  ['296441', 'Gary', 'Mann', 'M'],
#  ['342704', 'Roy', 'Nesvold', 'M'],
#  ['481295', 'Chris (I)', 'Tucker', 'M'],
#  ['511530', 'Ellis', 'Williams', 'M'],
#  ['512863', 'Herbert Hans', 'Wilmsen', 'M'],
#  ['534709', 'Tangie', 'Ambrose', 'F'],
#  ['553121', 'Michelle', 'Berube', 'F'],
#  ['563043', 'Candice', 'Briere', 'F'],
#  ['589246', 'Denise', 'Crosby', 'F'],
#  ['613869', 'Julia', 'Ervin', 'F'],
#  ['621910', 'Bridget', 'Fonda', 'F'],
#  ['637479', 'Aimee', 'Graham', 'F'],
#  ['639803', 'Pam', 'Grier', 'F'],
#  ['645258', 'Lisa Gay', 'Hamilton', 'F'],
#  ['674219', 'Renee (II)', 'Kelly', 'F'],
#  ['675497', "T'Keyah Crystal", 'KeymÃ¡h', 'F'],
#  ['699105', 'Juliet', 'Long', 'F'],
#  ['700526', 'Laura', 'Lovelace', 'F'],
#  ['702376', 'Christine', 'Lydon', 'F'],
#  ['714657', 'Colleen', 'Mayne', 'F'],
#  ['716971', 'Elizabeth', 'McInerney', 'F'],
#  ['819400', 'Diana', 'Uribe', 'F'],
#  ['820312', 'Venessia', 'Valentino', 'F'],
#  ['830721', 'Gillian Iliana', 'Waters', 'F'],
#  ['837246', 'Hattie', 'Winston', 'F'],
#  ['74449', 'David', 'Carradine', 'M'],
#  ['84199', 'Sonny', 'Chiba', 'M'],
#  ['106131', 'Goro', 'Daimon', 'M'],
#  ['216347', 'Xiaohui', 'Hu', 'M'],
#  ['249940', 'Kazuki', 'Kitamura', 'M'],
#  ['260069', 'Jun', 'Kunimura', 'M'],
#  ['260427', 'Michael', 'Kuroiwa', 'M'],
#  ['260737', 'Naomi', 'Kusumi', 'M'],
#  ['280984', 'Chia Hui', 'Liu', 'M'],
#  ['284742', 'Jonathan', 'Loughran', 'M'],
#  ['299922', 'Akaji', 'Maro', 'M'],
#  ['319868', 'Hikaru', 'Midorikawa', 'M'],
#  ['330833', 'Yoshiyuki', 'Morishita', 'M'],
#  ['341985', 'Christopher Allen', 'Nelson', 'M'],
#  ['352931', 'Kenji', 'Ohba', 'M'],
#  ['363245', 'James', 'Parks', 'M'],
#  ['363257', 'Michael (I)', 'Parks', 'M'],
#  ['378578', 'Stevo', 'Polyi', 'M'],
#  ['420990', 'Sakichi', 'SatÃ´', 'M'],
#  ['435415', 'Tetsuro', 'Shimaguchi', 'M'],
#  ['459441', 'Shun', 'Sugata', 'M'],
#  ['464802', 'Issei', 'Takahashi', 'M'],
#  ['465932', 'Yoji', 'Tanaka', 'M'],
#  ['519687', 'Satoshi', 'Yamanaka', 'M'],
#  ['525594', 'Zhang Jin', 'Zhan', 'M'],
#  ['606682', 'Julie', 'Dreyfus', 'F'],
#  ['623535', 'Vivica A.', 'Fox', 'F'],
#  ['626150', 'Sachiko', 'Fujii', 'F'],
#  ...]

# %%
# Creating another table with actors for testing purposes

extra_actors = [['109100', 'Renata', 'Dividino', 'F'],['481290', 'Burnell', 'Tucker', 'M'], ['10963', 'Chris', 'Anastasio', 'M']]
extra_actors
# Out:
# [['109100', 'Renata', 'Dividino', 'F'],
#  ['481290', 'Burnell', 'Tucker', 'M'],
#  ['10963', 'Chris', 'Anastasio', 'M']]

# %% [markdown]
# ## Implementing Relational Algebra Operators

# %% [markdown]
# ### Set Operators

# %%
# operator to merge two lists
def union(lst1, lst2):
    """Relational algebra project set union
    """ 
    ## IMPLEMENT HERE THE UNION OF TWO LISTS
    lst3 = lst1 + lst2
    return lst3

# %%
# operator to merge two lists with no duplicated allowed
def union2(lst1, lst2):
    """Relational algebra project set union with no duplicates
    """ 
    ## IMPLEMENT HERE THE UNION OF TWO LIST RETURNING NO DUPLICATES
    lst3 = lst1 + lst2
    lst4 = []
    for i in lst3:
        if i not in lst4:
            lst4.append(i)
    return lst4

# %%
# operator to perform the intersection of two lists
def intersection(lst1, lst2):
    """Relational algebra project set intersection
    """ 
    ###IMPLEMENT HERE THE INTERSECTION OF TWO LISTS
    lst3 = [value for value in lst1 if value in lst2]
    return lst3

# %%
# operator to perform the set difference of two lists
def set_difference(lst1, lst2):
    """Relational algebra project set difference
    """ 
    ## IMPLEMENT HERE THE SET DIFFERENT BETWEEN TWO LISTS
    lst3 = []
    for i in lst1:
        if i not in lst2:
            lst3.append(i)
    return lst3

# %% [markdown]
# Now Perform the union between the actors and extra_actors relation
# This operation should returns all of the rows of actor and extra_actors unioned in to a single list.

# %%
### ADD CODE HERE
## I used extra_actors as the first relation so we could see them at the top
union(extra_actors,actors)
intersection(extra_actors,actors)
# Out:
# [['481290', 'Burnell', 'Tucker', 'M'], ['10963', 'Chris', 'Anastasio', 'M']]

# %% [markdown]
# ### Selection

# %% [markdown]
# Now we can use a loop to perform selections on our data. For example we can create a list of all of the male actors:

# %%
def selection(relation, column, predicate, mode):
    """Relational algebra project selection
    """ 
    ## IMPLEMENT HERE THE SELECTION OPERATOR valid modes are ['<', '<=', '>', '>=', '==', '!=']
    modes = ['<', '<=', '>', '>=', '==', '!=']
    lst3 = []
    ops = {
    '==': operator.eq,
    '<': operator.lt,
    '<=': operator.le,
    '>': operator.gt,
    '>=': operator.ge,
    '!=': operator.ne
    }
    if mode in modes:
        for r in relation:
            if ops[mode](r[column], predicate):
                lst3.append(r)
        return lst3
    else:
        print ("Invalid mode")

# %% [markdown]
# Exercise:
# - Show all tuples from actors that first name is Chris
# - Show all tuples from movies that were made after 1998
# - Show all tuples from actors that are female AND id is bigger than 200000

# %%
## ADD CODE HERE
print("Tuples from actors that first name is Chris:")
actors_named_chris = selection(actors,1,"Chris",'==')
for tuple in actors_named_chris:
    print(tuple)
print("Tuples from movies that were made after 1998:")
movies_after = selection(movies,2,"1998",'>')
for tuple in movies_after:
    print(tuple)
print("Tuples from actors that are female AND id is bigger than 200000")
female_and = union(selection(actors,3,'F','=='),selection(actors,0,"200000",'>'))
for tuple in female_and:
    print(tuple)
# Out:
# Tuples from actors that first name is Chris:
# ['10963', 'Chris', 'Anastasio', 'M']
# ['432055', 'Chris', 'Shafer', 'M']
# ['99597', 'Chris', 'Cragnotti', 'M']
# ['362250', 'Chris', 'Pare', 'M']
# ['96626', 'Chris', 'Cornibert', 'M']
# ['307000', 'Chris', 'Maybach', 'M']
# Tuples from movies that were made after 1998:
# ['10934', 'Aliens of the Deep', '2005', '6.5']
# ['96779', 'Earthship.TV', '2001', '5.6']
# ['105938', 'Expedition: Bismarck', '2002', '7.5']
# ['127297', 'Ghosts of the Abyss', '2003', '6.7']
# ['385710', 'Dark Angel', '2000', '7.4']
# ['106666', 'Eyes Wide Shut', '1999', '7']
# ['159665', 'Inglorious Bastards', '2006', '8.3']
# ['176711', 'Kill Bill: Vol. 1', '2003', '8.4']
# ['176712', 'Kill Bill: Vol. 2', '2004', '8.2']
# ['393538', 'Jimmy Kimmel Live!', '2003', '6.7']
# Tuples from actors that are female AND id is bigger than 200000
# ['589318', 'Paula', 'Cross', 'F']
# ['636502', 'Wendy', 'Gordon', 'F']
# ['712889', 'Mary Elizabeth', 'Mastrantonio', 'F']
# ['785706', 'Kimberly (I)', 'Scott', 'F']
# ['840493', 'Emily', 'Yancy', 'F']
# ['583693', 'Barbara', 'Coles', 'F']
# ['583735', 'Valerie', 'Colgan', 'F']
# ['596318', 'Holly', 'De Jong', 'F']
# ['635153', 'Jenette', 'Goldstein', 'F']
# ['651551', 'Carrie', 'Henn', 'F']
# ['653997', 'Colette', 'Hiller', 'F']
# ['661430', 'Elizabeth', 'Inglis', 'F']
# ['748340', 'Alibe', 'Parsons', 'F']
# ['785581', 'Cynthia Dale', 'Scott', 'F']
# ['831289', 'Sigourney', 'Weaver', 'F']
# ['649578', 'Stacey', 'Hayes', 'F']
# ['667425', 'Dr. Lori', 'Johnston', 'F']
# ['758870', 'Judy', 'Prestininzi', 'F']
# ['768452', 'Dale (II)', 'Ridge', 'F']
# ['794639', 'Tava', 'Smiley', 'F']
# ['809044', 'Janace', 'Tashjian', 'F']
# ['819988', 'Adriana', 'Valdez', 'F']
# ['551641', 'Tracey', 'Berg', 'F']
# ['590307', 'Dorothy', 'Cunningham', 'F']
# ['594608', 'Carole (I)', 'Davis', 'F']
# ['638349', 'Leslie (I)', 'Graves', 'F']
# ['643627', 'Connie Lynn', 'Hadden', 'F']
# ['705207', 'Hildy', 'Magnasun', 'F']
# ['707687', 'Jan Eisner', 'Mannon', 'F']
# ['741046', 'Tricia', "O'Neil", 'F']
# ['756625', 'Anne', 'Pollack', 'F']
# ['767575', 'Sally', 'Ricca', 'F']
# ['832066', 'Myra', 'Weisler', 'F']
# ['645256', 'Linda (I)', 'Hamilton', 'F']
# ['563244', 'Lisa', 'Brinegar', 'F']
# ['588077', 'Nikki', 'Cox', 'F']
# ['597793', 'Gwenda', 'Deacon', 'F']
# ['608796', "Na'loni", 'Durden', 'F']
# ['614721', 'Noel', 'Evangelisti', 'F']
# ['620255', 'Nancy', 'Fish', 'F']
# ['645152', 'Leslie', 'Hamilton Gearren', 'F']
# ['720259', 'S. Epatha', 'Merkerson', 'F']
# ['771500', 'Diane', 'Rodriguez', 'F']
# ['828805', 'Misty Jo', 'Walker', 'F']
# ['624665', 'Loree', 'Frazier', 'F']
# ['659683', 'Hettie Lynne', 'Hurtes', 'F']
# ['718489', 'Harriet', 'Medin', 'F']
# ['730105', 'Bess', 'Motta', 'F']
# ['730692', 'Marianne', 'Muellerleile', 'F']
# ['758221', 'Barbara', 'Powers', 'F']
# ['783346', 'Shawn', 'Schepps', 'F']
# ['534915', 'Suzy', 'Amis', 'F']
# ['541702', 'Rosalind', 'Ayres', 'F']
# ['547276', 'Bobbie', 'Bates', 'F']
# ['547303', 'Kathy (I)', 'Bates', 'F']
# ['560216', 'Dawn M.', 'Bourn', 'F']
# ['560719', 'Alexandra', 'Boyd', 'F']
# ['562717', 'Fannie', 'Brett', 'F']
# ['578075', 'Charlotte', 'Chatton', 'F']
# ['608339', 'Kathleen S.', 'Dunn', 'F']
# ['620301', 'Frances (I)', 'Fisher', 'F']
# ['621016', 'Anne', 'Fletcher', 'F']
# ['627384', 'Amy', 'Gaipa', 'F']
# ['629712', 'Aimee Amanda', 'Garten', 'F']
# ['629713', 'Jo Lynn', 'Garten', 'F']
# ['653279', 'Andie', 'Hicks', 'F']
# ['659281', 'Samantha', 'Hunt', 'F']
# ['675117', 'Linda', 'Kerns', 'F']
# ['678541', 'Rebecca', 'Klingler', 'F']
# ['687048', 'Laramie', 'Landis', 'F']
# ['709423', 'Mandana', 'Marino', 'F']
# ['728576', 'Diana (II)', 'Morgan', 'F']
# ['740170', 'Ellen', "O'Brien", 'F']
# ['744930', 'Camilla', 'Overbye Roos', 'F']
# ['745079', 'Alexandrea', 'Owens', 'F']
# ['763718', 'Lisa', 'Ratzin', 'F']
# ['763862', 'Elsa', 'Raven', 'F']
# ['766230', 'Julene', 'Renee', 'F']
# ['773658', 'Rochelle', 'Rose', 'F']
# ['803835', 'Gloria', 'Stuart', 'F']
# ['827985', 'Alison', 'Waddell', 'F']
# ['827986', 'Amber', 'Waddell', 'F']
# ['837199', 'Kate', 'Winslet', 'F']
# ['573294', 'Tia', 'Carrere', 'F']
# ['577530', 'Katsy', 'Chappell', 'F']
# ['590629', 'Jamie Lee', 'Curtis', 'F']
# ['598141', 'Mary A.', 'DeBriae', 'F']
# ['608999', 'Eliza', 'Dushku', 'F']
# ['729268', 'Jane (I)', 'Morris', 'F']
# ['839732', 'Crystina', 'Wyler', 'F']
# ['819133', 'Margaret', 'Undiel', 'F']
# ['556737', 'Sheraton', 'Blount', 'F']
# ['559266', 'Ann', 'Bormann', 'F']
# ['561464', 'Penny', 'Brahms', 'F']
# ['573464', 'Edwina', 'Carroll', 'F']
# ['589087', 'Julie', 'Croft', 'F']
# ['606054', 'Heather', 'Downham', 'F']
# ['623949', 'Penny', 'Francis', 'F']
# ['633066', 'Ann (I)', 'Gillis', 'F']
# ['649736', 'Jane', 'Hayward', 'F']
# ['683135', 'Vivian', 'Kubrick', 'F']
# ['709642', 'Marcella', 'Markham', 'F']
# ['710214', 'Krystyna', 'Marr', 'F']
# ['735076', 'Kim', 'Neil', 'F']
# ['750078', 'Jane', 'Pearl', 'F']
# ['750089', 'Penny', 'Pearl', 'F']
# ['818459', 'Margaret', 'Tyzack', 'F']
# ['551488', 'Marisa', 'Berenson', 'F']
# ['645202', 'Gay', 'Hamilton', 'F']
# ['673249', 'Marie', 'Kean', 'F']
# ['684623', 'Diana', 'KÃ¶rner', 'F']
# ['529804', 'Jan', 'Adair', 'F']
# ['564580', 'Gaye', 'Brown', 'F']
# ['577143', 'Vivienne', 'Chandler', 'F']
# ['586737', 'Adrienne', 'Corri', 'F']
# ['606245', 'Prudence', 'Drage', 'F']
# ['606720', 'Carol', 'Drinkwater', 'F']
# ['640907', 'Cheryl', 'Grunwald', 'F']
# ['654069', 'Gillian', 'Hills', 'F']
# ['663573', 'Shirley', 'Jaffe', 'F']
# ['671758', 'Miriam', 'Karlin', 'F']
# ['764299', 'Sheila', 'Raynor', 'F']
# ['777198', 'Madge', 'Ryan', 'F']
# ['785548', 'Barbara (V)', 'Scott', 'F']
# ['809779', 'Pauline (I)', 'Taylor', 'F']
# ['833428', 'Virginia', 'Wetherell', 'F']
# ['839709', 'Katya', 'Wyeth', 'F']
# ['792995', 'Judy (I)', 'Singer', 'F']
# ['764987', 'Tracy (II)', 'Reed', 'F']
# ['539877', 'Karla', 'Ashley', 'F']
# ['573883', 'Heather', 'Carter-Drake', 'F']
# ['577756', 'Kathryn', 'Charman', 'F']
# ['594783', 'Julienne', 'Davis', 'F']
# ['602507', 'Janie', 'Dickens', 'F']
# ['604337', 'Cindy', 'Dolenc', 'F']
# ['611037', 'Madison', 'Eginton', 'F']
# ['615217', 'Donna', 'Ewin', 'F']
# ['616025', 'Laura', 'Fallace', 'F']
# ['617848', 'Vanessa (II)', 'Fenton', 'F']
# ['619666', 'Georgina', 'Finch', 'F']
# ['635912', 'Abigail', 'Good', 'F']
# ['645973', 'Tres', 'Hanley', 'F']
# ['649487', 'Clark (I)', 'Hayes', 'F']
# ['650090', 'Joanna', 'Heath', 'F']
# ['653067', 'Mariana', 'Hewett', 'F']
# ['675927', 'Nicole', 'Kidman', 'F']
# ['683132', 'Christiane', 'Kubrick', 'F']
# ['683134', 'Katharina', 'Kubrick', 'F']
# ['693690', 'Lisa (I)', 'Leone', 'F']
# ['700691', 'Leslie', 'Lowe', 'F']
# ['709994', 'Carmela', 'Marner', 'F']
# ['712865', 'Fay', 'Masterson', 'F']
# ['757084', 'Ateeka', 'Poole', 'F']
# ['761200', 'Sharon', 'Quinn', 'F']
# ['768088', 'Marie', 'Richardson', 'F']
# ['782497', 'Jackie', 'Sawiris', 'F']
# ['788960', 'Emma Lou', 'Sharratt', 'F']
# ['789192', 'Vinessa', 'Shaw', 'F']
# ['796007', 'Leelee', 'Sobieski', 'F']
# ['809699', 'Louise J.', 'Taylor', 'F']
# ['812607', 'Stewart', 'Thorndike', 'F']
# ['833537', 'Kate', 'Whalin', 'F']
# ['692929', 'Virginia', 'Leith', 'F']
# ['635367', 'Laurie', 'Gomes', 'F']
# ['656446', 'Leanne', 'Hong', 'F']
# ['690482', 'Ngoc', 'Le', 'F']
# ['796984', 'Papillon', 'Soo', 'F']
# ['561594', 'Barbara', 'Brand', 'F']
# ['670943', 'Irene', 'Kane', 'F']
# ['796029', 'Ruth', 'Sobotka', 'F']
# ['530012', 'Dorothy', 'Adams', 'F']
# ['573511', 'Mary (I)', 'Carroll', 'F']
# ['612055', 'Cecil', 'Elliott', 'F']
# ['638426', 'Coleen', 'Gray', 'F']
# ['836963', 'Marie', 'Windsor', 'F']
# ['598240', 'Diana', 'Decker', 'F']
# ['605798', 'Shirley', 'Douglas', 'F']
# ['632299', 'Susanne', 'Gibbs', 'F']
# ['655488', 'Maxine', 'Holden', 'F']
# ['701079', 'Isabelle', 'Lucas', 'F']
# ['702877', 'Sue', 'Lyon', 'F']
# ['713189', 'Marion', 'Mathie', 'F']
# ['714240', 'Lois', 'Maxwell', 'F']
# ['790816', 'Roberta', 'Shore', 'F']
# ['802676', 'Marianne', 'Stone', 'F']
# ['837410', 'Shelley', 'Winters', 'F']
# ['549455', 'Lia', 'Beldam', 'F']
# ['567465', 'Lisa (I)', 'Burns', 'F']
# ['567466', 'Louise (I)', 'Burns', 'F']
# ['583685', 'Alison', 'Coleridge', 'F']
# ['609183', 'Shelley', 'Duvall', 'F']
# ['632333', 'Billie', 'Gibson', 'F']
# ['662905', 'Anne', 'Jackson', 'F']
# ['747261', 'Robin', 'Pappas', 'F']
# ['753642', 'Kate', 'Phelps', 'F']
# ['789514', 'Jana', 'Sheldon', 'F']
# ['545547', 'Joanna', 'Barnes', 'F']
# ['621646', 'Nina', 'Foch', 'F']
# ['653783', 'Hallene', 'Hill', 'F']
# ['664711', 'Jil', 'Jarmyn', 'F']
# ['673529', 'Valley', 'Keene', 'F']
# ['776584', 'Autumn', 'Russell', 'F']
# ['792255', 'Jean (I)', 'Simmons', 'F']
# ['804889', 'Jo', 'Summers', 'F']
# ['825612', 'Louise', 'Vincent', 'F']
# ['548183', 'Jennifer (I)', 'Beals', 'F']
# ['594964', 'Sammi (I)', 'Davis', 'F']
# ['595847', 'Amanda', 'De Cadenet', 'F']
# ['635230', 'Valeria', 'Golino', 'F']
# ['639885', 'Kathy', 'Griffin', 'F']
# ['649455', 'Salma', 'Hayek', 'F']
# ['704821', 'Rikee', 'Madoff', 'F']
# ['715590', 'Unruly Julie', 'McClean', 'F']
# ['717432', 'Lana', 'McKissack', 'F']
# ['776475', 'Laura (I)', 'Rush', 'F']
# ['794051', 'Ione', 'Skye', 'F']
# ['809683', 'Lili', 'Taylor', 'F']
# ['814398', 'Marisa', 'Tomei', 'F']
# ['814439', 'Tamlyn', 'Tomita', 'F']
# ['827280', 'Patricia', 'Vonne', 'F']
# ['837678', 'Alicia', 'Witt', 'F']
# ['534709', 'Tangie', 'Ambrose', 'F']
# ['553121', 'Michelle', 'Berube', 'F']
# ['563043', 'Candice', 'Briere', 'F']
# ['589246', 'Denise', 'Crosby', 'F']
# ['613869', 'Julia', 'Ervin', 'F']
# ['621910', 'Bridget', 'Fonda', 'F']
# ['637479', 'Aimee', 'Graham', 'F']
# ['639803', 'Pam', 'Grier', 'F']
# ['645258', 'Lisa Gay', 'Hamilton', 'F']
# ['674219', 'Renee (II)', 'Kelly', 'F']
# ['675497', "T'Keyah Crystal", 'KeymÃ¡h', 'F']
# ['699105', 'Juliet', 'Long', 'F']
# ['700526', 'Laura', 'Lovelace', 'F']
# ['702376', 'Christine', 'Lydon', 'F']
# ['714657', 'Colleen', 'Mayne', 'F']
# ['716971', 'Elizabeth', 'McInerney', 'F']
# ['819400', 'Diana', 'Uribe', 'F']
# ['820312', 'Venessia', 'Valentino', 'F']
# ['830721', 'Gillian Iliana', 'Waters', 'F']
# ['837246', 'Hattie', 'Winston', 'F']
# ['606682', 'Julie', 'Dreyfus', 'F']
# ['623535', 'Vivica A.', 'Fox', 'F']
# ['626150', 'Sachiko', 'Fujii', 'F']
# ['626225', 'Ronnie Yoshiko', 'Fujiyama', 'F']
# ['646020', 'Daryl', 'Hannah', 'F']
# ['673153', 'Yuki', 'Kazamatsuri', 'F']
# ['673865', 'Ambrosia', 'Kelley', 'F']
# ['683804', 'Chiaki', 'Kuriyama', 'F']
# ['697645', 'Lucy', 'Liu', 'F']
# ['704920', 'Ai (III)', 'Maeda', 'F']
# ['706956', 'Julie', 'Manase', 'F']
# ['812916', 'Uma', 'Thurman', 'F']
# ['817238', 'Shu Lan', 'Tuan', 'F']
# ['840317', 'Yoshiko', 'Yamaguchi', 'F']
# ['549030', 'Reda', 'Beebe', 'F']
# ['557743', 'Citlati Guadalupe', 'Bojorquez', 'F']
# ['575732', 'Laura', 'Cayouette', 'F']
# ['589608', 'Lucia', 'Cruz Marroquin', 'F']
# ['596738', 'Maria', 'de Lourdes Lombera', 'F']
# ['599020', 'Maria', 'Del Rosario GutiÃ©rrez', 'F']
# ['613315', 'Jeannie', 'Epper', 'F']
# ['645886', 'Perla', 'Haney-Jardine', 'F']
# ['673358', 'Caitlin', 'Keats', 'F']
# ['676314', 'Helen (IV)', 'Kim', 'F']
# ['701044', 'Vicki', 'Lucai', 'F']
# ['711529', 'Veronica Janet', 'Martinez', 'F']
# ['727540', 'Stephanie L.', 'Moore', 'F']
# ['745520', 'Sonia Angelica', 'Padilla Curiel', 'F']
# ['773694', 'Thea', 'Rose', 'F']
# ['778957', 'Graciela', 'Salazar Mendoza', 'F']
# ['791868', 'Patricia', 'Silva', 'F']
# ['795587', 'Claire', 'Smithies', 'F']
# ['800701', 'Shana', 'Stein', 'F']
# ['654019', 'Brenda', 'Hillhouse', 'F']
# ['673070', 'Linda', 'Kaye', 'F']
# ['539150', 'Rosanna', 'Arquette', 'F']
# ['596862', 'Maria', 'de Medeiros', 'F']
# ['627760', 'Bronagh', 'Gallagher', 'F']
# ['640057', 'Susan', 'Griffiths', 'F']
# ['667689', 'Angela (I)', 'Jones', 'F']
# ['694110', 'Lorelei', 'Leslie', 'F']
# ['712086', 'Karen', 'Maruyama', 'F']
# ['756056', 'Amanda', 'Plummer', 'F']
# ['782153', 'Ani', 'Sava', 'F']
# ['806043', 'Julia', 'Sweeney', 'F']
# ['575999', 'Suzanne', 'Celeste', 'F']
# ['688902', 'Laurie', 'Latham', 'F']
# ['803695', 'Maria', 'Strova', 'F']
# ['32638', 'Michael', 'Beach', 'M']
# ['33949', 'John', 'Bedford Lloyd', 'M']
# ['42278', 'Michael', 'Biehn', 'M']
# ['57051', 'Captain Kidd', 'Brewer Jr.', 'M']
# ['64610', 'Leo', 'Burmester', 'M']
# ['69977', 'Mike (I)', 'Cameron', 'M']
# ['70419', 'J. Kenneth', 'Campbell', 'M']
# ['81503', 'Michael (I)', 'Chapman', 'M']
# ['223068', 'Tom', 'Isbell', 'M']
# ['228850', 'Ken (I)', 'Jenkins', 'M']
# ['250810', 'George Robert', 'Klek', 'M']
# ['281620', 'Frank (II)', 'Lloyd', 'M']
# ['334067', 'Marcus K.', 'Mukai', 'M']
# ['335612', 'Christopher (I)', 'Murphy', 'M']
# ['341916', 'Adam (I)', 'Nelson', 'M']
# ['342314', 'Joseph C.', 'Nemec III', 'M']
# ['386373', 'J.C.', 'Quinn', 'M']
# ['391009', 'Peter', 'Ratray', 'M']
# ['459752', 'Brad', 'Sullivan', 'M']
# ['502273', 'Dick', 'Warlock', 'M']
# ['504906', 'Jimmie Ray', 'Weeks', 'M']
# ['514734', 'William', 'Wisher Jr.', 'M']
# ['589318', 'Paula', 'Cross', 'F']
# ['636502', 'Wendy', 'Gordon', 'F']
# ['712889', 'Mary Elizabeth', 'Mastrantonio', 'F']
# ['785706', 'Kimberly (I)', 'Scott', 'F']
# ['840493', 'Emily', 'Yancy', 'F']
# ['36641', 'Jay (I)', 'Benedict', 'M']
# ['204493', 'Christopher', 'Henn', 'M']
# ['204719', 'Lance', 'Henriksen', 'M']
# ['213646', 'William', 'Hope', 'M']
# ['240277', 'Daniel', 'Kash', 'M']
# ['272557', 'John', 'Lees', 'M']
# ['305705', 'Al', 'Matthews', 'M']
# ['306790', 'Paul (I)', 'Maxwell', 'M']
# ['310030', 'Mac (I)', 'McDonald', 'M']
# ['366173', 'Bill', 'Paxton', 'M']
# ['378476', 'Alan', 'Polonsky', 'M']
# ['394516', 'Paul', 'Reiser', 'M']
# ['405572', 'Mark', 'Rolston', 'M']
# ['408215', 'Ricco', 'Ross', 'M']
# ['452549', 'Trevor', 'Steedman', 'M']
# ['474375', 'Tip', 'Tipping', 'M']
# ['476429', 'Carl', 'Toop', 'M']
# ['583693', 'Barbara', 'Coles', 'F']
# ['583735', 'Valerie', 'Colgan', 'F']
# ['596318', 'Holly', 'De Jong', 'F']
# ['635153', 'Jenette', 'Goldstein', 'F']
# ['651551', 'Carrie', 'Henn', 'F']
# ['653997', 'Colette', 'Hiller', 'F']
# ['661430', 'Elizabeth', 'Inglis', 'F']
# ['748340', 'Alibe', 'Parsons', 'F']
# ['785581', 'Cynthia Dale', 'Scott', 'F']
# ['831289', 'Sigourney', 'Weaver', 'F']
# ['69940', 'James (I)', 'Cameron', 'M']
# ['232844', 'Dean (VII)', 'Jones', 'M']
# ['259373', 'Karl (II)', 'Kuhn', 'M']
# ['285456', 'Curt', 'Lowens', 'M']
# ['428322', 'Ty', 'Sears', 'M']
# ['432055', 'Chris', 'Shafer', 'M']
# ['452552', 'Heinz', 'Steeg', 'M']
# ['460992', 'Blake', 'Sutton', 'M']
# ['505504', 'Walter', 'Weintz', 'M']
# ['518333', 'Kai', 'Wulff', 'M']
# ['933', 'Lewis', 'Abernathy', 'M']
# ['24256', 'Jesse (II)', 'Baker', 'M']
# ['24288', 'Justin (II)', 'Baker', 'M']
# ['58357', 'Dr. John', 'Broadwater', 'M']
# ['61439', 'John (I)', 'Bruno', 'M']
# ['83459', 'Genya', 'Chernaiev', 'M']
# ['227895', 'Corey', 'Jaskolski', 'M']
# ['247406', 'Thomas', 'Kilroy', 'M']
# ['271226', 'Jeffrey N.', 'Ledda', 'M']
# ['288312', 'Don (II)', 'Lynch', 'M']
# ['300455', 'Ken', 'Marschall', 'M']
# ['346051', 'Victor', 'Nischeta', 'M']
# ['358828', 'Vince', 'Pace', 'M']
# ['365476', 'Jason (II)', 'Paul', 'M']
# ['367826', 'Charles (I)', 'Pellegrino', 'M']
# ['414913', 'Dr. Anatoly M.', 'Sagalevitch', 'M']
# ['424651', 'Eric', 'Schmitz', 'M']
# ['433468', 'Justin', 'Shaw', 'M']
# ['510823', 'Miguel', 'Wilkins', 'M']
# ['523925', 'Federico', 'Zambrano', 'M']
# ['649578', 'Stacey', 'Hayes', 'F']
# ['667425', 'Dr. Lori', 'Johnston', 'F']
# ['758870', 'Judy', 'Prestininzi', 'F']
# ['768452', 'Dale (II)', 'Ridge', 'F']
# ['794639', 'Tava', 'Smiley', 'F']
# ['809044', 'Janace', 'Tashjian', 'F']
# ['819988', 'Adriana', 'Valdez', 'F']
# ['91252', 'Phil', 'Colby', 'M']
# ['223545', 'Paul', 'Issa', 'M']
# ['258459', 'Lee', 'Krug', 'M']
# ['297529', 'Steve', 'Marachuk', 'M']
# ['359763', 'Jim', 'Pair', 'M']
# ['388685', 'Johnny', 'Ralston', 'M']
# ['398113', 'Ted', 'Richert', 'M']
# ['407927', 'Arnie', 'Ross', 'M']
# ['418091', 'Albert (I)', 'Sanders', 'M']
# ['508939', 'Ward', 'White', 'M']
# ['521874', 'Aston S.', 'Young', 'M']
# ['551641', 'Tracey', 'Berg', 'F']
# ['590307', 'Dorothy', 'Cunningham', 'F']
# ['594608', 'Carole (I)', 'Davis', 'F']
# ['638349', 'Leslie (I)', 'Graves', 'F']
# ['643627', 'Connie Lynn', 'Hadden', 'F']
# ['705207', 'Hildy', 'Magnasun', 'F']
# ['707687', 'Jan Eisner', 'Mannon', 'F']
# ['741046', 'Tricia', "O'Neil", 'F']
# ['756625', 'Anne', 'Pollack', 'F']
# ['767575', 'Sally', 'Ricca', 'F']
# ['832066', 'Myra', 'Weisler', 'F']
# ['47595', 'Earl', 'Boen', 'M']
# ['257870', 'Mark', 'Kriski', 'M']
# ['364956', 'Robert (I)', 'Patrick', 'M']
# ['426628', 'Arnold', 'Schwarzenegger', 'M']
# ['645256', 'Linda (I)', 'Hamilton', 'F']
# ['450', 'Dalton', 'Abbott', 'M']
# ['39044', 'Xander', 'Berkeley', 'M']
# ['39129', 'Ennalls', 'Berl', 'M']
# ['59799', 'Charles Robert', 'Brown', 'M']
# ['82660', 'Casey', 'Chavez', 'M']
# ['95086', 'Danny', 'Cooksey', 'M']
# ['233988', 'J. Rob', 'Jordan', 'M']
# ['255881', 'Pat', 'Kouri', 'M']
# ['263765', 'Don', 'Lake', 'M']
# ['269396', 'Mark Christopher', 'Lawrence', 'M']
# ['279903', 'Van', 'Ling', 'M']
# ['284866', 'Jared', 'Lounsbery', 'M']
# ['288301', 'Colin Patrick', 'Lynch', 'M']
# ['310084', 'Tom (I)', 'McDonald', 'M']
# ['332070', 'Joe', 'Morton', 'M']
# ['336379', 'Mike', 'Muscat', 'M']
# ['346378', 'DeVaughn', 'Nixon', 'M']
# ['347730', 'Dean', 'Norris', 'M']
# ['360529', 'Jim (I)', 'Palmer', 'M']
# ['374220', 'Denney', 'Pierce', 'M']
# ['425673', 'Peter', 'Schrum', 'M']
# ['433531', 'Scott (I)', 'Shaw', 'M']
# ['439561', 'Tony', 'Simotes', 'M']
# ['451689', 'Dan', 'Stanton', 'M']
# ['451692', 'Don', 'Stanton', 'M']
# ['465636', 'Charles A.', 'Tamburro', 'M']
# ['493307', 'Richard', 'Vidan', 'M']
# ['510502', 'Shane', 'Wilder', 'M']
# ['511606', 'Gerard G.', 'Williams', 'M']
# ['514131', 'Robert', 'Winley', 'M']
# ['522268', 'Ron (I)', 'Young', 'M']
# ['563244', 'Lisa', 'Brinegar', 'F']
# ['588077', 'Nikki', 'Cox', 'F']
# ['597793', 'Gwenda', 'Deacon', 'F']
# ['608796', "Na'loni", 'Durden', 'F']
# ['614721', 'Noel', 'Evangelisti', 'F']
# ['620255', 'Nancy', 'Fish', 'F']
# ['645152', 'Leslie', 'Hamilton Gearren', 'F']
# ['720259', 'S. Epatha', 'Merkerson', 'F']
# ['771500', 'Diane', 'Rodriguez', 'F']
# ['828805', 'Misty Jo', 'Walker', 'F']
# ['58045', 'John E.', 'Bristol', 'M']
# ['92891', 'Franco', 'Columbu', 'M']
# ['236878', 'Al', 'Kahn', 'M']
# ['245075', 'Bruce M.', 'Kerner', 'M']
# ['321383', 'Dick (I)', 'Miller', 'M']
# ['323583', 'Tony', 'Mirelez', 'M']
# ['331400', 'Leslie (I)', 'Morris', 'M']
# ['351978', 'Tom', 'Oberhaus', 'M']
# ['374217', 'David (II)', 'Pierce', 'M']
# ['375423', 'Patrick', 'Pinney', 'M']
# ['388681', 'James', 'Ralston', 'M']
# ['392215', 'Brad', 'Rearden', 'M']
# ['398193', 'Bill W.', 'Richmond', 'M']
# ['401041', 'Gregory', 'Robbins', 'M']
# ['408622', 'Rick', 'Rossovich', 'M']
# ['456639', 'Wayne', 'Stone', 'M']
# ['472024', 'Brian (I)', 'Thompson', 'M']
# ['480252', 'Anthony', 'Trujillo', 'M']
# ['511368', "Chino 'Fats'", 'Williams', 'M']
# ['512349', 'Webster', 'Williams', 'M']
# ['513935', 'Paul', 'Winfield', 'M']
# ['519450', 'Stan', 'Yale', 'M']
# ['624665', 'Loree', 'Frazier', 'F']
# ['659683', 'Hettie Lynne', 'Hurtes', 'F']
# ['718489', 'Harriet', 'Medin', 'F']
# ['730105', 'Bess', 'Motta', 'F']
# ['730692', 'Marianne', 'Muellerleile', 'F']
# ['758221', 'Barbara', 'Powers', 'F']
# ['783346', 'Shawn', 'Schepps', 'F']
# ['2898', 'Seth (I)', 'Adkins', 'M']
# ['29603', 'Jason', 'Barry', 'M']
# ['54608', 'Eric', 'Braeden', 'M']
# ['57665', 'Paul', 'Brightwell', 'M']
# ['66328', 'Mike', 'Butters', 'M']
# ['66776', 'Chris (I)', 'Byrne', 'M']
# ['70744', 'Bruno', 'Campolo', 'M']
# ['72215', 'Mark', 'Capri', 'M']
# ['76228', 'Nicholas', 'Cascone', 'M']
# ['76443', 'Aaron James', 'Cash', 'M']
# ['76653', 'Marc', 'Cass', 'M']
# ['81499', 'Mark Lindsay', 'Chapman', 'M']
# ['93883', 'Brendan', 'Connolly', 'M']
# ['95037', 'Gregory (I)', 'Cooke', 'M']
# ['99597', 'Chris', 'Cragnotti', 'M']
# ['99941', 'Simon (I)', 'Crane', 'M']
# ['205287', 'Paul (IV)', 'Herbert', 'M']
# ['208287', 'Bernard', 'Hill', 'M']
# ['209729', 'Scott', 'Hislop', 'M']
# ['211832', 'Erik', 'Holland', 'M']
# ['216473', 'Martin', 'Hub', 'M']
# ['219643', 'Jonathan', 'Hyde', 'M']
# ['226351', 'Emmett', 'James', 'M']
# ['227836', 'Martin', 'Jarvis', 'M']
# ['230528', 'Rudy', 'Joffroy', 'M']
# ['243306', 'Craig (II)', 'Kelly', 'M']
# ['244575', 'Tony (I)', 'Kenny', 'M']
# ['248904', 'Jari (I)', 'Kinnunen', 'M']
# ['263645', 'Martin (I)', 'Laing', 'M']
# ['264813', 'James', 'Lancaster', 'M']
# ['270444', 'Derek', 'Lea', 'M']
# ['283561', 'Shep', 'Lonsdale', 'M']
# ['301563', 'Johnny (I)', 'Martin', 'M']
# ['307547', 'Stan', 'Mazin', 'M']
# ['313916', 'Nick', 'Meaney', 'M']
# ['335829', 'Patrick (IV)', 'Murphy', 'M']
# ['342443', 'Sean', 'Nepita', 'M']
# ['348858', 'Danny', 'Nucci', 'M']
# ['351253', 'Mike (II)', "O'Neal", 'M']
# ['354484', 'BjÃ¸rn (I)', 'Olsen', 'M']
# ['358426', 'Kevin', 'Owers', 'M']
# ['359448', 'Oliver', 'Page', 'M']
# ['360793', 'Lew', 'Palter', 'M']
# ['372149', 'Dan (I)', 'Pettersson', 'M']
# ['373241', 'Jonathan (I)', 'Phillips', 'M']
# ['444656', 'Stephen Wolfe', 'Smith', 'M']
# ['455151', 'Ewan (I)', 'Stewart', 'M']
# ['462918', 'BÃ©la', 'SzedlÃ¡k', 'M']
# ['462919', 'Ferenc', 'SzedlÃ¡k', 'M']
# ['468177', 'Rocky (I)', 'Taylor', 'M']
# ['471961', 'Reece P.', 'Thompson III', 'M']
# ['480062', 'R. Gern', 'Trowbridge', 'M']
# ['480247', 'Mark Rafael', 'Truitt', 'M']
# ['481840', 'Liam', 'Tuohy', 'M']
# ['482854', 'Stephen', 'Twigger', 'M']
# ['484826', 'Vern', 'Urich', 'M']
# ['497962', 'Francisco', 'VÃ¡ldez', 'M']
# ['499298', 'John', 'Walcutt', 'M']
# ['500666', 'Brian (II)', 'Walsh', 'M']
# ['502344', 'David (I)', 'Warner', 'M']
# ['505031', 'Stephen', 'Wehmeyer', 'M']
# ['513645', 'Garth', 'Wilton', 'M']
# ['524132', 'Billy', 'Zane', 'M']
# ['534915', 'Suzy', 'Amis', 'F']
# ['541702', 'Rosalind', 'Ayres', 'F']
# ['547276', 'Bobbie', 'Bates', 'F']
# ['547303', 'Kathy (I)', 'Bates', 'F']
# ['560216', 'Dawn M.', 'Bourn', 'F']
# ['560719', 'Alexandra', 'Boyd', 'F']
# ['562717', 'Fannie', 'Brett', 'F']
# ['578075', 'Charlotte', 'Chatton', 'F']
# ['608339', 'Kathleen S.', 'Dunn', 'F']
# ['620301', 'Frances (I)', 'Fisher', 'F']
# ['621016', 'Anne', 'Fletcher', 'F']
# ['627384', 'Amy', 'Gaipa', 'F']
# ['629712', 'Aimee Amanda', 'Garten', 'F']
# ['629713', 'Jo Lynn', 'Garten', 'F']
# ['653279', 'Andie', 'Hicks', 'F']
# ['659281', 'Samantha', 'Hunt', 'F']
# ['675117', 'Linda', 'Kerns', 'F']
# ['678541', 'Rebecca', 'Klingler', 'F']
# ['687048', 'Laramie', 'Landis', 'F']
# ['709423', 'Mandana', 'Marino', 'F']
# ['728576', 'Diana (II)', 'Morgan', 'F']
# ['740170', 'Ellen', "O'Brien", 'F']
# ['744930', 'Camilla', 'Overbye Roos', 'F']
# ['745079', 'Alexandrea', 'Owens', 'F']
# ['763718', 'Lisa', 'Ratzin', 'F']
# ['763862', 'Elsa', 'Raven', 'F']
# ['766230', 'Julene', 'Renee', 'F']
# ['773658', 'Rochelle', 'Rose', 'F']
# ['803835', 'Gloria', 'Stuart', 'F']
# ['827985', 'Alison', 'Waddell', 'F']
# ['827986', 'Amber', 'Waddell', 'F']
# ['837199', 'Kate', 'Winslet', 'F']
# ['4961', 'Mike', 'Akrawi', 'M']
# ['7991', 'James (IV)', 'Allen', 'M']
# ['29743', 'Paul', 'Barselou', 'M']
# ['99596', 'Charles', 'Cragin', 'M']
# ['206867', 'Grant', 'Heslov', 'M']
# ['207002', 'Charlton', 'Heston', 'M']
# ['220569', 'Majed', 'Ibrahim', 'M']
# ['258898', 'Armen', 'Ksajikian', 'M']
# ['294609', 'Art', 'Malik', 'M']
# ['295961', 'Marshall', 'Manesh', 'M']
# ['298368', 'Louai', 'Mardini', 'M']
# ['346027', 'Andre', 'Nirmel', 'M']
# ['362022', 'Jean-Claude', 'Parachini', 'M']
# ['362418', 'Erik', 'Parillo', 'M']
# ['370282', 'Manuel', 'Perry', 'M']
# ['373813', 'Charlie (I)', 'Picerni', 'M']
# ['391197', 'Dieter', 'Rauter', 'M']
# ['416883', 'Gino', 'Salvano', 'M']
# ['417399', 'Ofer', 'Samra', 'M']
# ['573294', 'Tia', 'Carrere', 'F']
# ['577530', 'Katsy', 'Chappell', 'F']
# ['590629', 'Jamie Lee', 'Curtis', 'F']
# ['598141', 'Mary A.', 'DeBriae', 'F']
# ['608999', 'Eliza', 'Dushku', 'F']
# ['729268', 'Jane (I)', 'Morris', 'F']
# ['839732', 'Crystina', 'Wyler', 'F']
# ['819133', 'Margaret', 'Undiel', 'F']
# ['33046', 'Robert (I)', 'Beatty', 'M']
# ['33492', 'Glenn', 'Beck', 'M']
# ['35269', 'Jimmy', 'Bell', 'M']
# ['43766', 'Ed (I)', 'Bishop', 'M']
# ['81735', 'David', 'Charkham', 'M']
# ['89366', 'John (I)', 'Clifford', 'M']
# ['200989', 'Brian (I)', 'Hawley', 'M']
# ['209041', 'David (I)', 'Hines', 'M']
# ['225060', 'Tony (I)', 'Jackson', 'M']
# ['234019', 'John (X)', 'Jordan', 'M']
# ['244025', 'Kenneth', 'Kendall', 'M']
# ['282170', 'Gary', 'Lockwood', 'M']
# ['285138', 'Mike', 'Lovell', 'M']
# ['290958', 'Scott', 'MacKee', 'M']
# ['297912', 'Laurence', 'Marchant', 'M']
# ['321439', 'Frank (I)', 'Miller', 'M']
# ['359269', 'Darryl', 'Paes', 'M']
# ['388177', 'Douglas', 'Rain', 'M']
# ['393452', 'Joe', 'Refalo', 'M']
# ['398261', 'Daniel (I)', 'Richter', 'M']
# ['408577', 'Leonard', 'Rossiter', 'M']
# ['427619', 'Kevin (I)', 'Scott', 'M']
# ['459935', 'Sean (I)', 'Sullivan', 'M']
# ['462236', 'John', 'Swindells', 'M']
# ['462532', 'William', 'Sylvester', 'M']
# ['481290', 'Burnell', 'Tucker', 'M']
# ['500110', 'Andy (I)', 'Wallace', 'M']
# ['507612', 'Bill (I)', 'Weston', 'M']
# ['513676', 'Bob', 'Wilyman', 'M']
# ['517018', 'Richard (II)', 'Woods', 'M']
# ['556737', 'Sheraton', 'Blount', 'F']
# ['559266', 'Ann', 'Bormann', 'F']
# ['561464', 'Penny', 'Brahms', 'F']
# ['573464', 'Edwina', 'Carroll', 'F']
# ['589087', 'Julie', 'Croft', 'F']
# ['606054', 'Heather', 'Downham', 'F']
# ['623949', 'Penny', 'Francis', 'F']
# ['633066', 'Ann (I)', 'Gillis', 'F']
# ['649736', 'Jane', 'Hayward', 'F']
# ['683135', 'Vivian', 'Kubrick', 'F']
# ['709642', 'Marcella', 'Markham', 'F']
# ['710214', 'Krystyna', 'Marr', 'F']
# ['735076', 'Kim', 'Neil', 'F']
# ['750078', 'Jane', 'Pearl', 'F']
# ['750089', 'Penny', 'Pearl', 'F']
# ['818459', 'Margaret', 'Tyzack', 'F']
# ['39086', 'Steven', 'Berkoff', 'M']
# ['43127', 'John', 'Bindon', 'M']
# ['50074', 'Roger', 'Booth', 'M']
# ['53692', 'Billy', 'Boyle', 'M']
# ['78776', 'Jonathan', 'Cecil', 'M']
# ['79048', 'Peter', 'Cellier', 'M']
# ['82337', 'Geoffrey', 'Chater', 'M']
# ['205176', 'Bernard', 'Hepton', 'M']
# ['206431', 'Anthony', 'Herrick', 'M']
# ['213908', 'Michael', 'Hordern', 'M']
# ['224581', 'Barry (I)', 'Jackson', 'M']
# ['236863', 'Wolf', 'Kahler', 'M']
# ['258862', 'Hardy', 'KrÃ¼ger', 'M']
# ['263045', 'Patrick', 'Laffan', 'M']
# ['292390', 'Patrick (I)', 'Magee', 'M']
# ['307261', 'Ferdy', 'Mayne', 'M']
# ['315871', 'Murray', 'Melvin', 'M']
# ['318503', 'Hans (I)', 'Meyer', 'M']
# ['319779', 'Frank', 'Middlemass', 'M']
# ['329794', 'AndrÃ©', 'Morell', 'M']
# ['330937', 'David', 'Morley', 'M']
# ['351264', 'Ryan', "O'Neal", 'M']
# ['351681', 'Arthur', "O'Sullivan", 'M']
# ['386178', 'Godfrey', 'Quigley', 'M']
# ['392783', 'Liam', 'Redmond', 'M']
# ['400860', 'Pat', 'Roach', 'M']
# ['421372', 'Dominic', 'Savage', 'M']
# ['423761', 'Frederick', 'Schiller', 'M']
# ['431642', 'George', 'Sewell', 'M']
# ['433046', 'Anthony', 'Sharp', 'M']
# ['433086', 'John (I)', 'Sharp', 'M']
# ['449193', 'Roy', 'Spencer', 'M']
# ['456570', 'Philip (I)', 'Stone', 'M']
# ['459849', 'John (I)', 'Sullivan', 'M']
# ['467844', 'Gary (II)', 'Taylor', 'M']
# ['477807', 'Harry', 'Towb', 'M']
# ['495397', 'Leon', 'Vitali', 'M']
# ['551488', 'Marisa', 'Berenson', 'F']
# ['645202', 'Gay', 'Hamilton', 'F']
# ['673249', 'Marie', 'Kean', 'F']
# ['684623', 'Diana', 'KÃ¶rner', 'F']
# ['31234', 'Michael (I)', 'Bates', 'M']
# ['65405', 'Peter', 'Burton', 'M']
# ['70489', 'Lindsay (I)', 'Campbell', 'M']
# ['73946', 'John J.', 'Carney', 'M']
# ['88544', 'Warren', 'Clarke', 'M']
# ['89519', 'John', 'Clive', 'M']
# ['93696', 'Richard', 'Connaught', 'M']
# ['95089', 'Barrie', 'Cookson', 'M']
# ['208928', 'Heinrich', 'Himmler', 'M']
# ['209799', 'Adolf', 'Hitler', 'M']
# ['218405', 'Craig (I)', 'Hunter', 'M']
# ['287974', 'Viktor', 'Lutze', 'M']
# ['298288', 'James (II)', 'Marcus', 'M']
# ['310213', 'Malcolm', 'McDowell', 'M']
# ['331189', 'Aubrey', 'Morris', 'M']
# ['350799', 'George', "O'Gorman", 'M']
# ['383596', 'David', 'Prowse', 'M']
# ['421615', 'John', 'Savident', 'M']
# ['466779', 'Michael', 'Tarn', 'M']
# ['513394', 'Neil (I)', 'Wilson', 'M']
# ['529804', 'Jan', 'Adair', 'F']
# ['564580', 'Gaye', 'Brown', 'F']
# ['577143', 'Vivienne', 'Chandler', 'F']
# ['586737', 'Adrienne', 'Corri', 'F']
# ['606245', 'Prudence', 'Drage', 'F']
# ['606720', 'Carol', 'Drinkwater', 'F']
# ['640907', 'Cheryl', 'Grunwald', 'F']
# ['654069', 'Gillian', 'Hills', 'F']
# ['663573', 'Shirley', 'Jaffe', 'F']
# ['671758', 'Miriam', 'Karlin', 'F']
# ['764299', 'Sheila', 'Raynor', 'F']
# ['777198', 'Madge', 'Ryan', 'F']
# ['785548', 'Barbara (V)', 'Scott', 'F']
# ['809779', 'Pauline (I)', 'Taylor', 'F']
# ['833428', 'Virginia', 'Wetherell', 'F']
# ['839709', 'Katya', 'Wyeth', 'F']
# ['75587', 'Vincent', 'Cartier', 'M']
# ['75588', 'Walter', 'Cartier', 'M']
# ['226249', 'Bobby (II)', 'James', 'M']
# ['259066', 'Stanley', 'Kubrick', 'M']
# ['440126', 'Alexander', 'Singer', 'M']
# ['792995', 'Judy (I)', 'Singer', 'F']
# ['40172', 'Frank (I)', 'Berry', 'M']
# ['63409', 'Peter (I)', 'Bull', 'M']
# ['201256', 'Sterling', 'Hayden', 'M']
# ['205401', 'Laurence', 'Herder', 'M']
# ['233082', 'James Earl', 'Jones', 'M']
# ['308556', 'John (I)', 'McCarthy', 'M']
# ['351321', 'Robert (I)', "O'Neil", 'M']
# ['373935', 'Slim (I)', 'Pickens', 'M']
# ['399367', 'Shane', 'Rimmer', 'M']
# ['427460', 'George C.', 'Scott', 'M']
# ['429719', 'Peter', 'Sellers', 'M']
# ['453983', 'Roy', 'Stephens', 'M']
# ['465553', 'Paul', 'Tamarin', 'M']
# ['466257', 'Gordon (II)', 'Tanner', 'M']
# ['518686', 'Keenan', 'Wynn', 'M']
# ['764987', 'Tracy (II)', 'Reed', 'F']
# ['37627', 'Peter (III)', 'Benson', 'M']
# ['88365', 'Christian (II)', 'Clarke', 'M']
# ['93702', 'Kevin', 'Connealy', 'M']
# ['94781', 'Brian W.', 'Cook', 'M']
# ['205014', 'Lee', 'Henshaw', 'M']
# ['210176', 'Alex', 'Hobbs', 'M']
# ['220892', 'Togo', 'Igawa', 'M']
# ['260733', 'Eiji', 'Kusuhara', 'M']
# ['277792', 'Adam', 'Lias', 'M']
# ['290708', 'Angus', 'MacInnes', 'M']
# ['362250', 'Chris', 'Pare', 'M']
# ['365531', 'Randall', 'Paul', 'M']
# ['370217', 'Gavin', 'Perry', 'M']
# ['378271', 'Sydney', 'Pollack', 'M']
# ['384073', 'Adam', 'Pudney', 'M']
# ['405530', 'Dan', 'Rollman', 'M']
# ['430641', 'Rade', 'Serbedzija', 'M']
# ['448978', 'Paul', 'Spelling', 'M']
# ['472331', 'Matthew (II)', 'Thompson', 'M']
# ['478574', 'Dan', 'Travers', 'M']
# ['479388', 'Russell', 'Trigg', 'M']
# ['508334', 'Kyle', 'Whitcombe', 'M']
# ['513864', 'Florian', 'Windorfer', 'M']
# ['539877', 'Karla', 'Ashley', 'F']
# ['573883', 'Heather', 'Carter-Drake', 'F']
# ['577756', 'Kathryn', 'Charman', 'F']
# ['594783', 'Julienne', 'Davis', 'F']
# ['602507', 'Janie', 'Dickens', 'F']
# ['604337', 'Cindy', 'Dolenc', 'F']
# ['611037', 'Madison', 'Eginton', 'F']
# ['615217', 'Donna', 'Ewin', 'F']
# ['616025', 'Laura', 'Fallace', 'F']
# ['617848', 'Vanessa (II)', 'Fenton', 'F']
# ['619666', 'Georgina', 'Finch', 'F']
# ['635912', 'Abigail', 'Good', 'F']
# ['645973', 'Tres', 'Hanley', 'F']
# ['649487', 'Clark (I)', 'Hayes', 'F']
# ['650090', 'Joanna', 'Heath', 'F']
# ['653067', 'Mariana', 'Hewett', 'F']
# ['675927', 'Nicole', 'Kidman', 'F']
# ['683132', 'Christiane', 'Kubrick', 'F']
# ['683134', 'Katharina', 'Kubrick', 'F']
# ['693690', 'Lisa (I)', 'Leone', 'F']
# ['700691', 'Leslie', 'Lowe', 'F']
# ['709994', 'Carmela', 'Marner', 'F']
# ['712865', 'Fay', 'Masterson', 'F']
# ['757084', 'Ateeka', 'Poole', 'F']
# ['761200', 'Sharon', 'Quinn', 'F']
# ['768088', 'Marie', 'Richardson', 'F']
# ['782497', 'Jackie', 'Sawiris', 'F']
# ['788960', 'Emma Lou', 'Sharratt', 'F']
# ['789192', 'Vinessa', 'Shaw', 'F']
# ['796007', 'Leelee', 'Sobieski', 'F']
# ['809699', 'Louise J.', 'Taylor', 'F']
# ['812607', 'Stewart', 'Thorndike', 'F']
# ['833537', 'Kate', 'Whalin', 'F']
# ['7872', 'David (IX)', 'Allen', 'M']
# ['91059', 'Stephen', 'Coit', 'M']
# ['307631', 'Paul', 'Mazursky', 'M']
# ['438416', 'Frank', 'Silvera', 'M']
# ['692929', 'Virginia', 'Leith', 'F']
# ['209787', 'Bob (II)', 'Hite', 'M']
# ['450798', 'Fred', 'Stadmueller', 'M']
# ['2397', 'Martin (I)', 'Adams', 'M']
# ['5871', 'Kevin', 'Albridge', 'M']
# ['23587', 'Philip', 'Bailey', 'M']
# ['25000', 'Adam', 'Baldwin', 'M']
# ['28036', 'Louis', 'Barlotti', 'M']
# ['33920', 'John', 'Beddows', 'M']
# ['37048', 'Patrick', 'Benn', 'M']
# ['46980', 'Bruce', 'Boa', 'M']
# ['51909', 'Steve', 'Boucher', 'M']
# ['65610', 'Adrian', 'Bush', 'M']
# ['73009', 'Tony (II)', 'Carey', 'M']
# ['82885', 'Gary', 'Cheeseman', 'M']
# ['84498', 'Costas Dino', 'Chimona', 'M']
# ['88311', 'Wayne (I)', 'Clark', 'M']
# ['91262', 'Tim', 'Colceri', 'M']
# ['96626', 'Chris', 'Cornibert', 'M']
# ['96627', 'Danny', 'Cornibert', 'M']
# ['201301', 'Barry', 'Hayes', 'M']
# ['201490', 'Tony (II)', 'Hayes', 'M']
# ['201936', 'Kenneth', 'Head', 'M']
# ['202517', 'Robin', 'Hedgeland', 'M']
# ['204833', 'Duncan', 'Henry', 'M']
# ['210579', 'Keith', 'Hodiak', 'M']
# ['211209', 'Liam', 'Hogan', 'M']
# ['211245', 'Trevor', 'Hogan', 'M']
# ['211261', 'Luke', 'Hogdal', 'M']
# ['215357', 'Arliss', 'Howard', 'M']
# ['215534', 'Kevyn Major', 'Howard', 'M']
# ['215643', 'Tony', 'Howard', 'M']
# ['216936', 'Steve (II)', 'Hudson', 'M']
# ['228364', 'Kieron', 'Jecchinis', 'M']
# ['254447', 'Gil', 'Kopel', 'M']
# ['264558', 'Sean', 'Lamming', 'M']
# ['265128', 'Dan (I)', 'Landin', 'M']
# ['272581', 'Tony', 'Leete', 'M']
# ['283927', 'Sal', 'Lopez', 'M']
# ['284721', 'Nigel', 'Lough', 'M']
# ['285408', 'Terry (I)', 'Lowe', 'M']
# ['307000', 'Chris', 'Maybach', 'M']
# ['308458', 'Frank', 'McCardle', 'M']
# ['317493', 'Peter', 'Merrill', 'M']
# ['318493', 'Gary (I)', 'Meyer', 'M']
# ['319786', 'Brett', 'Middleton', 'M']
# ['322263', 'Gary Landon', 'Mills', 'M']
# ['322448', 'David (I)', 'Milner', 'M']
# ['323110', 'Sean', 'Minmagh', 'M']
# ['323111', 'Tony', 'Minmagh', 'M']
# ['325263', 'Matthew', 'Modine', 'M']
# ['331636', 'John (VIII)', 'Morrison', 'M']
# ['332927', 'Russell', 'Mott', 'M']
# ['342634', 'John', 'Ness', 'M']
# ['344407', 'Robert (V)', 'Nichols', 'M']
# ['348031', 'Herbert', 'Norville', 'M']
# ['351565', 'Ed', "O'Ross", 'M']
# ['360186', 'David', 'Palffy', 'M']
# ['370184', 'David (I)', 'Perry', 'M']
# ['373513', 'Nguyen Hue', 'Phong', 'M']
# ['406269', 'Peter', 'Rommely', 'M']
# ['418550', 'Pat', 'Sands', 'M']
# ['420532', 'Jim', 'Sarup', 'M']
# ['439592', 'Al (I)', 'Simpson', 'M']
# ['442258', 'Russell', 'Slater', 'M']
# ['443772', 'Gary (I)', 'Smith', 'M']
# ['444548', 'Roger (VI)', 'Smith', 'M']
# ['444747', 'Tony (II)', 'Smith', 'M']
# ['450874', 'Jon', 'Stafford', 'M']
# ['458996', 'Anthony', 'Styliano', 'M']
# ['464072', 'Duc Hu', 'Ta', 'M']
# ['468001', 'Kirk', 'Taylor', 'M']
# ['469867', 'John (I)', 'Terry', 'M']
# ['472006', 'Bill (IV)', 'Thompson', 'M']
# ['482081', 'Mike', 'Turjansky', 'M']
# ['482993', 'Ian', 'Tyler', 'M']
# ['506029', 'Dan (I)', 'Weldon', 'M']
# ['506265', 'Dennis', 'Wells', 'M']
# ['511949', 'Michael (III)', 'Williams', 'M']
# ['513249', 'John (V)', 'Wilson', 'M']
# ['515954', 'John', 'Wonderling', 'M']
# ['635367', 'Laurie', 'Gomes', 'F']
# ['656446', 'Leanne', 'Hong', 'F']
# ['690482', 'Ngoc', 'Le', 'F']
# ['796984', 'Papillon', 'Soo', 'F']
# ['2753', 'Skippy', 'Adelman', 'M']
# ['227733', 'Jerry', 'Jarret', 'M']
# ['350108', 'Shaun', "O'Brien", 'M']
# ['355874', 'Felice', 'Orlandi', 'M']
# ['401685', 'Ralph (I)', 'Roberts', 'M']
# ['410475', 'Alec', 'Rubin', 'M']
# ['443960', 'Jamie (I)', 'Smith', 'M']
# ['454948', 'Phil', 'Stevenson', 'M']
# ['490228', 'David (I)', 'Vaughan', 'M']
# ['561594', 'Barbara', 'Brand', 'F']
# ['670943', 'Irene', 'Kane', 'F']
# ['796029', 'Ruth', 'Sobotka', 'F']
# ['2949', 'Jay', 'Adler', 'M']
# ['36662', "William 'Billy'", 'Benedict', 'M']
# ['71122', 'Charles', 'Cane', 'M']
# ['73002', 'Timothy', 'Carey', 'M']
# ['94748', 'Elisha', 'Cook Jr.', 'M']
# ['261145', 'Kola', 'Kwariani', 'M']
# ['324376', 'Steve (I)', 'Mitchell', 'M']
# ['328560', 'Hal J.', 'Moore', 'M']
# ['393428', 'Richard (I)', 'Reeves', 'M']
# ['397677', 'Frank (I)', 'Richards', 'M']
# ['421893', 'Joe', 'Sawyer', 'M']
# ['482105', 'Joe', 'Turkel', 'M']
# ['497834', 'Tito', 'Vuolo', 'M']
# ['512106', 'Robert (I)', 'Williams', 'M']
# ['530012', 'Dorothy', 'Adams', 'F']
# ['573511', 'Mary (I)', 'Carroll', 'F']
# ['612055', 'Cecil', 'Elliott', 'F']
# ['638426', 'Coleen', 'Gray', 'F']
# ['836963', 'Marie', 'Windsor', 'F']
# ['7976', 'Irvin', 'Allen', 'M']
# ['55062', 'Roland', 'Brand', 'M']
# ['90262', 'Gary', 'Cockrell', 'M']
# ['247182', 'Terry', 'Kilburn', 'M']
# ['265390', 'Eric (I)', 'Lane', 'M']
# ['271543', 'Christopher (I)', 'Lee', 'M']
# ['279385', 'Cec', 'Linder', 'M']
# ['293607', 'Colin', 'Maitland', 'M']
# ['303906', 'James (I)', 'Mason', 'M']
# ['358119', 'Robert C.', 'Overton', 'M']
# ['417404', 'Craig', 'Sams', 'M']
# ['457044', 'Jerry', 'Stovin', 'M']
# ['502490', 'C. Denier', 'Warren', 'M']
# ['598240', 'Diana', 'Decker', 'F']
# ['605798', 'Shirley', 'Douglas', 'F']
# ['632299', 'Susanne', 'Gibbs', 'F']
# ['655488', 'Maxine', 'Holden', 'F']
# ['701079', 'Isabelle', 'Lucas', 'F']
# ['702877', 'Sue', 'Lyon', 'F']
# ['713189', 'Marion', 'Mathie', 'F']
# ['714240', 'Lois', 'Maxwell', 'F']
# ['790816', 'Roberta', 'Shore', 'F']
# ['802676', 'Marianne', 'Stone', 'F']
# ['837410', 'Shelley', 'Winters', 'F']
# ['35214', 'Fred', 'Bell', 'M']
# ['36638', 'Harold', 'Benedict', 'M']
# ['57565', 'Leon', 'Briggs', 'M']
# ['67337', 'Paul', 'BÃ¶s', 'M']
# ['71871', 'Peter', 'Capell', 'M']
# ['200578', 'Jerry', 'Hausner', 'M']
# ['256772', 'Rolf', 'Kralovitz', 'M']
# ['291501', 'George', 'Macready', 'M']
# ['314498', 'Ralph', 'Meeker', 'M']
# ['316559', 'Adolphe', 'Menjou', 'M']
# ['318477', 'Emile', 'Meyer', 'M']
# ['328569', 'Ira', 'Moore', 'M']
# ['331537', 'Wayne (I)', 'Morris', 'M']
# ['388222', 'Marshall', 'Rainer', 'M']
# ['453199', 'John (I)', 'Stein', 'M']
# ['485541', 'Roger', 'Vagnoid', 'M']
# ['211966', 'Dan', 'Hollenbeck', 'M']
# ['32161', 'David', 'Baxt', 'M']
# ['65437', 'Tony (I)', 'Burton', 'M']
# ['281601', 'Danny', 'Lloyd', 'M']
# ['341935', 'Barry (I)', 'Nelson', 'M']
# ['344454', 'Jack', 'Nicholson', 'M']
# ['392853', 'Manning', 'Redwood', 'M']
# ['549455', 'Lia', 'Beldam', 'F']
# ['567465', 'Lisa (I)', 'Burns', 'F']
# ['567466', 'Louise (I)', 'Burns', 'F']
# ['583685', 'Alison', 'Coleridge', 'F']
# ['609183', 'Shelley', 'Duvall', 'F']
# ['632333', 'Billie', 'Gibson', 'F']
# ['662905', 'Anne', 'Jackson', 'F']
# ['747261', 'Robin', 'Pappas', 'F']
# ['753642', 'Kate', 'Phelps', 'F']
# ['789514', 'Jana', 'Sheldon', 'F']
# ['31073', 'Arthur', 'Batanides', 'M']
# ['44648', 'Bill (II)', 'Blackburn', 'M']
# ['54507', 'Buff', 'Brady', 'M']
# ['58391', 'Peter', 'Brocco', 'M']
# ['63265', 'Rudy', 'Bukich', 'M']
# ['64809', 'Bob (VII)', 'Burns', 'M']
# ['64945', 'Paul E.', 'Burns', 'M']
# ['71744', 'Joe', 'Canutt', 'M']
# ['71745', 'Tap', 'Canutt', 'M']
# ['73734', 'Al', 'Carmichael', 'M']
# ['98633', 'Chuck', 'Courtney', 'M']
# ['201016', 'Joe', 'Haworth', 'M']
# ['201022', 'Vinton', 'Haworth', 'M']
# ['201721', 'Chuck (I)', 'Hayward', 'M']
# ['214562', 'Charles', 'Horvath', 'M']
# ['216081', 'John (I)', 'Hoyt', 'M']
# ['222590', 'John (I)', 'Ireland', 'M']
# ['248067', 'Aron', 'Kincaid', 'M']
# ['258492', 'Stubby', 'Kruger', 'M']
# ['264368', 'Paul (I)', 'Lambert', 'M']
# ['268316', 'Charles', 'Laughton', 'M']
# ['282409', 'Carey', 'Loftin', 'M']
# ['282811', 'Herbert', 'Lom', 'M']
# ['287067', 'Dayton', 'Lummis', 'M']
# ['288617', 'Cliff', 'Lyons', 'M']
# ['311083', 'Charles', 'McGraw', 'M']
# ['324189', 'Gordon (I)', 'Mitchell', 'M']
# ['330244', 'Bob (I)', 'Morgan', 'M']
# ['330245', "Boyd 'Red'", 'Morgan', 'M']
# ['354242', 'Laurence', 'Olivier', 'M']
# ['362896', 'Eddie (I)', 'Parker', 'M']
# ['363632', 'Harvey', 'Parry', 'M']
# ['363813', 'Regis', 'Parton', 'M']
# ['368411', 'Leonard', 'Penn', 'M']
# ['369626', 'Gil', 'Perkins', 'M']
# ['370058', 'Vic', 'Perrin', 'M']
# ['388308', 'Bill', 'Raisch', 'M']
# ['401160', 'Chuck', 'Roberson', 'M']
# ['402707', 'George', 'Robotham', 'M']
# ['421223', 'Russell (II)', 'Saunders', 'M']
# ['422745', 'Charles (I)', 'Schaeffer', 'M']
# ['428306', 'Jim', 'Sears', 'M']
# ['452742', 'Tom (I)', 'Steele', 'M']
# ['454955', 'Robert (II)', 'Stevenson', 'M']
# ['456479', 'Harold (I)', 'Stone', 'M']
# ['458043', 'Woody', 'Strode', 'M']
# ['469772', 'Ken', 'Terrell', 'M']
# ['485123', 'Peter', 'Ustinov', 'M']
# ['488449', 'Dale', 'Van Sickel', 'M']
# ['510708', 'Robert J.', 'Wilke', 'M']
# ['517411', 'Frederick', 'Worlock', 'M']
# ['521921', 'Carleton', 'Young', 'M']
# ['545547', 'Joanna', 'Barnes', 'F']
# ['621646', 'Nina', 'Foch', 'F']
# ['653783', 'Hallene', 'Hill', 'F']
# ['664711', 'Jil', 'Jarmyn', 'F']
# ['673529', 'Valley', 'Keene', 'F']
# ['776584', 'Autumn', 'Russell', 'F']
# ['792255', 'Jean (I)', 'Simmons', 'F']
# ['804889', 'Jo', 'Summers', 'F']
# ['825612', 'Louise', 'Vincent', 'F']
# ['26023', 'Antonio', 'Banderas', 'M']
# ['36472', 'Lawrence', 'Bender', 'M']
# ['68754', 'Paul', 'Calderon', 'M']
# ['243102', 'Quinn Thomas', 'Kellerman', 'M']
# ['269386', 'Marc (I)', 'Lawrence', 'M']
# ['383529', 'David', 'Proval', 'M']
# ['408902', 'Tim', 'Roth', 'M']
# ['441448', 'Paul', 'Skemp', 'M']
# ['466585', 'Quentin', 'Tarantino', 'M']
# ['491878', 'Danny', 'Verduzco', 'M']
# ['497371', 'Russell', 'Vossler', 'M']
# ['512541', 'Bruce', 'Willis', 'M']
# ['548183', 'Jennifer (I)', 'Beals', 'F']
# ['594964', 'Sammi (I)', 'Davis', 'F']
# ['595847', 'Amanda', 'De Cadenet', 'F']
# ['635230', 'Valeria', 'Golino', 'F']
# ['639885', 'Kathy', 'Griffin', 'F']
# ['649455', 'Salma', 'Hayek', 'F']
# ['704821', 'Rikee', 'Madoff', 'F']
# ['715590', 'Unruly Julie', 'McClean', 'F']
# ['717432', 'Lana', 'McKissack', 'F']
# ['776475', 'Laura (I)', 'Rush', 'F']
# ['794051', 'Ione', 'Skye', 'F']
# ['809683', 'Lili', 'Taylor', 'F']
# ['814398', 'Marisa', 'Tomei', 'F']
# ['814439', 'Tamlyn', 'Tomita', 'F']
# ['827280', 'Patricia', 'Vonne', 'F']
# ['837678', 'Alicia', 'Witt', 'F']
# ['292028', 'Michael (I)', 'Madsen', 'M']
# ['52978', 'Michael (I)', 'Bowen', 'M']
# ['225014', 'Samuel L.', 'Jackson', 'M']
# ['242194', 'Michael', 'Keaton', 'M']
# ['280645', "Tom 'Tiny'", 'Lister Jr.', 'M']
# ['296441', 'Gary', 'Mann', 'M']
# ['342704', 'Roy', 'Nesvold', 'M']
# ['481295', 'Chris (I)', 'Tucker', 'M']
# ['511530', 'Ellis', 'Williams', 'M']
# ['512863', 'Herbert Hans', 'Wilmsen', 'M']
# ['534709', 'Tangie', 'Ambrose', 'F']
# ['553121', 'Michelle', 'Berube', 'F']
# ['563043', 'Candice', 'Briere', 'F']
# ['589246', 'Denise', 'Crosby', 'F']
# ['613869', 'Julia', 'Ervin', 'F']
# ['621910', 'Bridget', 'Fonda', 'F']
# ['637479', 'Aimee', 'Graham', 'F']
# ['639803', 'Pam', 'Grier', 'F']
# ['645258', 'Lisa Gay', 'Hamilton', 'F']
# ['674219', 'Renee (II)', 'Kelly', 'F']
# ['675497', "T'Keyah Crystal", 'KeymÃ¡h', 'F']
# ['699105', 'Juliet', 'Long', 'F']
# ['700526', 'Laura', 'Lovelace', 'F']
# ['702376', 'Christine', 'Lydon', 'F']
# ['714657', 'Colleen', 'Mayne', 'F']
# ['716971', 'Elizabeth', 'McInerney', 'F']
# ['819400', 'Diana', 'Uribe', 'F']
# ['820312', 'Venessia', 'Valentino', 'F']
# ['830721', 'Gillian Iliana', 'Waters', 'F']
# ['837246', 'Hattie', 'Winston', 'F']
# ['74449', 'David', 'Carradine', 'M']
# ['84199', 'Sonny', 'Chiba', 'M']
# ['216347', 'Xiaohui', 'Hu', 'M']
# ['249940', 'Kazuki', 'Kitamura', 'M']
# ['260069', 'Jun', 'Kunimura', 'M']
# ['260427', 'Michael', 'Kuroiwa', 'M']
# ['260737', 'Naomi', 'Kusumi', 'M']
# ['280984', 'Chia Hui', 'Liu', 'M']
# ['284742', 'Jonathan', 'Loughran', 'M']
# ['299922', 'Akaji', 'Maro', 'M']
# ['319868', 'Hikaru', 'Midorikawa', 'M']
# ['330833', 'Yoshiyuki', 'Morishita', 'M']
# ['341985', 'Christopher Allen', 'Nelson', 'M']
# ['352931', 'Kenji', 'Ohba', 'M']
# ['363245', 'James', 'Parks', 'M']
# ['363257', 'Michael (I)', 'Parks', 'M']
# ['378578', 'Stevo', 'Polyi', 'M']
# ['420990', 'Sakichi', 'SatÃ´', 'M']
# ['435415', 'Tetsuro', 'Shimaguchi', 'M']
# ['459441', 'Shun', 'Sugata', 'M']
# ['464802', 'Issei', 'Takahashi', 'M']
# ['465932', 'Yoji', 'Tanaka', 'M']
# ['519687', 'Satoshi', 'Yamanaka', 'M']
# ['525594', 'Zhang Jin', 'Zhan', 'M']
# ['606682', 'Julie', 'Dreyfus', 'F']
# ['623535', 'Vivica A.', 'Fox', 'F']
# ['626150', 'Sachiko', 'Fujii', 'F']
# ['626225', 'Ronnie Yoshiko', 'Fujiyama', 'F']
# ['646020', 'Daryl', 'Hannah', 'F']
# ['673153', 'Yuki', 'Kazamatsuri', 'F']
# ['673865', 'Ambrosia', 'Kelley', 'F']
# ['683804', 'Chiaki', 'Kuriyama', 'F']
# ['697645', 'Lucy', 'Liu', 'F']
# ['704920', 'Ai (III)', 'Maeda', 'F']
# ['706956', 'Julie', 'Manase', 'F']
# ['812916', 'Uma', 'Thurman', 'F']
# ['817238', 'Shu Lan', 'Tuan', 'F']
# ['840317', 'Yoshiko', 'Yamaguchi', 'F']
# ['43802', 'Larry', 'Bishop', 'M']
# ['88326', 'William Paul', 'Clark', 'M']
# ['319795', 'Clark', 'Middleton', 'M']
# ['438134', 'Jorge (II)', 'Silva', 'M']
# ['461413', 'Bo', 'Svenson', 'M']
# ['549030', 'Reda', 'Beebe', 'F']
# ['557743', 'Citlati Guadalupe', 'Bojorquez', 'F']
# ['575732', 'Laura', 'Cayouette', 'F']
# ['589608', 'Lucia', 'Cruz Marroquin', 'F']
# ['596738', 'Maria', 'de Lourdes Lombera', 'F']
# ['599020', 'Maria', 'Del Rosario GutiÃ©rrez', 'F']
# ['613315', 'Jeannie', 'Epper', 'F']
# ['645886', 'Perla', 'Haney-Jardine', 'F']
# ['673358', 'Caitlin', 'Keats', 'F']
# ['676314', 'Helen (IV)', 'Kim', 'F']
# ['701044', 'Vicki', 'Lucai', 'F']
# ['711529', 'Veronica Janet', 'Martinez', 'F']
# ['727540', 'Stephanie L.', 'Moore', 'F']
# ['745520', 'Sonia Angelica', 'Padilla Curiel', 'F']
# ['773694', 'Thea', 'Rose', 'F']
# ['778957', 'Graciela', 'Salazar Mendoza', 'F']
# ['791868', 'Patricia', 'Silva', 'F']
# ['795587', 'Claire', 'Smithies', 'F']
# ['800701', 'Shana', 'Stein', 'F']
# ['417719', 'Alan', 'Sanborn', 'M']
# ['482416', 'Rich', 'Turner', 'M']
# ['498580', 'Rowland', 'Wafford', 'M']
# ['654019', 'Brenda', 'Hillhouse', 'F']
# ['673070', 'Linda', 'Kaye', 'F']
# ['7817', 'Carl (I)', 'Allen', 'M']
# ['45243', 'Don', 'Blakely', 'M']
# ['65536', 'Steve', 'Buscemi', 'M']
# ['87969', 'Eric (I)', 'Clark', 'M']
# ['207426', 'Stephen', 'Hibbert', 'M']
# ['210153', 'Jerome Patrick', 'Hoban', 'M']
# ['242760', 'Harvey', 'Keitel', 'M']
# ['264162', 'Phil', 'LaMarr', 'M']
# ['279222', 'Chandler', 'Lindauer', 'M']
# ['362817', 'Brad (I)', 'Parker', 'M']
# ['374784', 'Joseph', 'Pilato', 'M']
# ['396528', 'Ving', 'Rhames', 'M']
# ['412573', 'Robert', 'Ruth', 'M']
# ['434562', 'Sy', 'Sher', 'M']
# ['436214', 'Gary', 'Shorelle', 'M']
# ['441022', 'Emil', 'Sitka', 'M']
# ['452838', 'Burr', 'Steers', 'M']
# ['456313', 'Eric', 'Stoltz', 'M']
# ['478676', 'John', 'Travolta', 'M']
# ['499566', 'Christopher', 'Walken', 'M']
# ['507903', 'Frank', 'Whaley', 'M']
# ['508288', 'Duane', 'Whitaker', 'M']
# ['539150', 'Rosanna', 'Arquette', 'F']
# ['596862', 'Maria', 'de Medeiros', 'F']
# ['627760', 'Bronagh', 'Gallagher', 'F']
# ['640057', 'Susan', 'Griffiths', 'F']
# ['667689', 'Angela (I)', 'Jones', 'F']
# ['694110', 'Lorelei', 'Leslie', 'F']
# ['712086', 'Karen', 'Maruyama', 'F']
# ['756056', 'Amanda', 'Plummer', 'F']
# ['782153', 'Ani', 'Sava', 'F']
# ['806043', 'Julia', 'Sweeney', 'F']
# ['25743', 'Kirk', 'Baltz', 'M']
# ['59227', 'Randy (I)', 'Brooks', 'M']
# ['63695', 'Edward', 'Bunker', 'M']
# ['97566', 'Tony', 'Cosmo', 'M']
# ['368399', 'Chris (I)', 'Penn', 'M']
# ['447813', 'Michael', 'Sottile', 'M']
# ['452774', 'David (I)', 'Steen', 'M']
# ['473634', 'Lawrence', 'Tierney', 'M']
# ['518086', 'Steven (I)', 'Wright', 'M']
# ['575999', 'Suzanne', 'Celeste', 'F']
# ['688902', 'Laurie', 'Latham', 'F']
# ['803695', 'Maria', 'Strova', 'F']

# %% [markdown]
# ### Projection

# %% [markdown]
# Now we want to implement the projection operator.

# %%
def project(relation, columns):
    """Relational algebra project operator
    
       relation: list of rows
       columns: list with columns index
    """
    # IMPLEMENT HERE THE PROJECT OPERATOR. THE FUNCTION ACCEPTS A LIST OF COLUMNS INDEXES AND RETURN THE VALUES OF THOSE COLUMNS 
    lst3 = []
    for i in relation:
        temp = []
        for j in columns:
            temp.append(i[j])
        lst3.append(temp)
    return lst3

# %% [markdown]
# Exercise:
#
# - Find the last name of all actors named Chris
# - Find the names of the movies that were made after 1998
# - Find the name of actors that are female AND id is bigger than 200000

# %%
## ADD CODE HERE
print("Last Name of all Actors named Chris:")
last_name = project(selection(actors,1,"Chris","=="),[2])
for name in last_name:
    print(name[0])
print("Names of the movies that were made after 1998:")
movie_name = project(selection(movies,2,"1998",'>'),[1])
for name in movie_name:
    print(name[0])
print("Names of actors that are female AND id is bigger than 200000:")
actor_name = project(union(selection(actors,3,'F','=='),selection(actors,0,"200000",'>')),[1,2])
for name in actor_name:
    print(name[0],name[1])
# Out:
# Last Name of all Actors named Chris:
# Anastasio
# Shafer
# Cragnotti
# Pare
# Cornibert
# Maybach
# Names of the movies that were made after 1998:
# Aliens of the Deep
# Earthship.TV
# Expedition: Bismarck
# Ghosts of the Abyss
# Dark Angel
# Eyes Wide Shut
# Inglorious Bastards
# Kill Bill: Vol. 1
# Kill Bill: Vol. 2
# Jimmy Kimmel Live!
# Names of actors that are female AND id is bigger than 200000:
# Paula Cross
# Wendy Gordon
# Mary Elizabeth Mastrantonio
# Kimberly (I) Scott
# Emily Yancy
# Barbara Coles
# Valerie Colgan
# Holly De Jong
# Jenette Goldstein
# Carrie Henn
# Colette Hiller
# Elizabeth Inglis
# Alibe Parsons
# Cynthia Dale Scott
# Sigourney Weaver
# Stacey Hayes
# Dr. Lori Johnston
# Lawrence Tierney
# Steven (I) Wright
# Suzanne Celeste
# Laurie Latham
# Maria Strova

# %% [markdown]
# ### Cross Product

# %% [markdown]
# Lets implement the cross product next. The cross product pairs each row of a relation with every row of another relation to create a new relation that contains every possible combination of the input relations tuples.

# %%
def crossproduct(relation_a, relation_b):
    ## IMPLEMENT CROSS PRODUCT HERE
    newrelation = []
    for a in relation_a:
        for b in relation_b:
            newrelation.append(a+b)
    return newrelation

# %% [markdown]
# To test our cross product function take the cross product of actors and movies

# %%
## ADD CODE
crossproduct(actors,movies)
# Out:
# [['10963', 'Chris', 'Anastasio', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['10963', 'Chris', 'Anastasio', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['10963', 'Chris', 'Anastasio', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['10963', 'Chris', 'Anastasio', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['10963', 'Chris', 'Anastasio', 'M', '340799', 'True Lies', '1994', '7'],
#  ['10963', 'Chris', 'Anastasio', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['10963', 'Chris', 'Anastasio', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['10963', 'Chris', 'Anastasio', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['10963', 'Chris', 'Anastasio', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['10963', 'Chris', 'Anastasio', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['10963', 'Chris', 'Anastasio', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['10963', 'Chris', 'Anastasio', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['10963', 'Chris', 'Anastasio', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['10963', 'Chris', 'Anastasio', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['10963', 'Chris', 'Anastasio', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['10963', 'Chris', 'Anastasio', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['10963', 'Chris', 'Anastasio', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['10963', 'Chris', 'Anastasio', 'M', '387728', 'ER', '1994', '7.7'],
#  ['10963',
#   'Chris',
#   'Anastasio',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['32638', 'Michael', 'Beach', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['32638', 'Michael', 'Beach', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['32638', 'Michael', 'Beach', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['32638', 'Michael', 'Beach', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['32638', 'Michael', 'Beach', 'M', '340799', 'True Lies', '1994', '7'],
#  ['32638', 'Michael', 'Beach', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['32638', 'Michael', 'Beach', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['32638', 'Michael', 'Beach', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['32638', 'Michael', 'Beach', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['32638', 'Michael', 'Beach', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['32638', 'Michael', 'Beach', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['32638', 'Michael', 'Beach', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['32638', 'Michael', 'Beach', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['32638', 'Michael', 'Beach', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
#  ['32638', 'Michael', 'Beach', 'M', '291833', 'Seafarers, The', '1953', '6.3'],
#  ['32638', 'Michael', 'Beach', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['32638', 'Michael', 'Beach', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['32638', 'Michael', 'Beach', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['32638', 'Michael', 'Beach', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['32638', 'Michael', 'Beach', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['32638', 'Michael', 'Beach', 'M', '276217', 'Reservoir Dogs', '1992', '8.3'],
#  ['32638', 'Michael', 'Beach', 'M', '387728', 'ER', '1994', '7.7'],
#  ['32638',
#   'Michael',
#   'Beach',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '340799', 'True Lies', '1994', '7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['33949', 'John', 'Bedford Lloyd', 'M', '387728', 'ER', '1994', '7.7'],
#  ['33949',
#   'John',
#   'Bedford Lloyd',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['42278', 'Michael', 'Biehn', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['42278', 'Michael', 'Biehn', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['42278', 'Michael', 'Biehn', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['42278', 'Michael', 'Biehn', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['42278', 'Michael', 'Biehn', 'M', '340799', 'True Lies', '1994', '7'],
#  ['42278', 'Michael', 'Biehn', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['42278', 'Michael', 'Biehn', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['42278', 'Michael', 'Biehn', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['42278', 'Michael', 'Biehn', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['42278', 'Michael', 'Biehn', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['42278', 'Michael', 'Biehn', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['42278', 'Michael', 'Biehn', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['42278', 'Michael', 'Biehn', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['42278', 'Michael', 'Biehn', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
#  ['42278', 'Michael', 'Biehn', 'M', '291833', 'Seafarers, The', '1953', '6.3'],
#  ['42278', 'Michael', 'Biehn', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['42278', 'Michael', 'Biehn', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['42278', 'Michael', 'Biehn', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['42278', 'Michael', 'Biehn', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['42278', 'Michael', 'Biehn', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['42278', 'Michael', 'Biehn', 'M', '276217', 'Reservoir Dogs', '1992', '8.3'],
#  ['42278', 'Michael', 'Biehn', 'M', '387728', 'ER', '1994', '7.7'],
#  ['42278',
#   'Michael',
#   'Biehn',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '5306',
#   'Abyss, The',
#   '1989',
#   '7.4'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '10920',
#   'Aliens',
#   '1986',
#   '8.2'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '333856',
#   'Titanic',
#   '1997',
#   '6.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '340799',
#   'True Lies',
#   '1994',
#   '7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '193519',
#   'Lolita',
#   '1962',
#   '7.6'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '310455',
#   'Spartacus',
#   '1960',
#   '8'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['57051', 'Captain Kidd', 'Brewer Jr.', 'M', '387728', 'ER', '1994', '7.7'],
#  ['57051',
#   'Captain Kidd',
#   'Brewer Jr.',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['64610', 'Leo', 'Burmester', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['64610', 'Leo', 'Burmester', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['64610', 'Leo', 'Burmester', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['64610', 'Leo', 'Burmester', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['64610', 'Leo', 'Burmester', 'M', '340799', 'True Lies', '1994', '7'],
#  ['64610', 'Leo', 'Burmester', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['64610', 'Leo', 'Burmester', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['64610', 'Leo', 'Burmester', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['64610', 'Leo', 'Burmester', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['64610', 'Leo', 'Burmester', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['64610', 'Leo', 'Burmester', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['64610', 'Leo', 'Burmester', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['64610', 'Leo', 'Burmester', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['64610', 'Leo', 'Burmester', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
#  ['64610', 'Leo', 'Burmester', 'M', '291833', 'Seafarers, The', '1953', '6.3'],
#  ['64610', 'Leo', 'Burmester', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['64610', 'Leo', 'Burmester', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['64610', 'Leo', 'Burmester', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['64610', 'Leo', 'Burmester', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['64610', 'Leo', 'Burmester', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['64610', 'Leo', 'Burmester', 'M', '276217', 'Reservoir Dogs', '1992', '8.3'],
#  ['64610', 'Leo', 'Burmester', 'M', '387728', 'ER', '1994', '7.7'],
#  ['64610',
#   'Leo',
#   'Burmester',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '340799', 'True Lies', '1994', '7'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['69977', 'Mike (I)', 'Cameron', 'M', '387728', 'ER', '1994', '7.7'],
#  ['69977',
#   'Mike (I)',
#   'Cameron',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '340799', 'True Lies', '1994', '7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['70419', 'J. Kenneth', 'Campbell', 'M', '387728', 'ER', '1994', '7.7'],
#  ['70419',
#   'J. Kenneth',
#   'Campbell',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '340799', 'True Lies', '1994', '7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['81503', 'Michael (I)', 'Chapman', 'M', '387728', 'ER', '1994', '7.7'],
#  ['81503',
#   'Michael (I)',
#   'Chapman',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['108530', 'Phillip', 'Darlington', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['108530', 'Phillip', 'Darlington', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['108530', 'Phillip', 'Darlington', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['108530', 'Phillip', 'Darlington', 'M', '340799', 'True Lies', '1994', '7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['108530', 'Phillip', 'Darlington', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['108530', 'Phillip', 'Darlington', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['108530', 'Phillip', 'Darlington', 'M', '387728', 'ER', '1994', '7.7'],
#  ['108530',
#   'Phillip',
#   'Darlington',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '340799', 'True Lies', '1994', '7'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['130508', 'Thomas F.', 'Duffy', 'M', '387728', 'ER', '1994', '7.7'],
#  ['130508',
#   'Thomas F.',
#   'Duffy',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '340799', 'True Lies', '1994', '7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['138073', 'Chris (I)', 'Elliott', 'M', '387728', 'ER', '1994', '7.7'],
#  ['138073',
#   'Chris (I)',
#   'Elliott',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['145064', 'Joe', 'Farago', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['145064', 'Joe', 'Farago', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['145064', 'Joe', 'Farago', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['145064', 'Joe', 'Farago', 'M', '328285', 'Terminator, The', '1984', '7.9'],
#  ['145064', 'Joe', 'Farago', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['145064', 'Joe', 'Farago', 'M', '340799', 'True Lies', '1994', '7'],
#  ['145064', 'Joe', 'Farago', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['145064', 'Joe', 'Farago', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['145064', 'Joe', 'Farago', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['145064', 'Joe', 'Farago', 'M', '79846', 'Day of the Fight', '1951', '6.3'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['145064', 'Joe', 'Farago', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['145064', 'Joe', 'Farago', 'M', '110246', 'Fear and Desire', '1953', '6.1'],
#  ['145064', 'Joe', 'Farago', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['145064',
#   'Joe',
#   'Farago',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['145064', 'Joe', 'Farago', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['145064', 'Joe', 'Farago', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['145064', 'Joe', 'Farago', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['145064', 'Joe', 'Farago', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
# ...
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '310455',
#   'Spartacus',
#   '1960',
#   '8'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['335612', 'Christopher (I)', 'Murphy', 'M', '387728', 'ER', '1994', '7.7'],
#  ['335612',
#   'Christopher (I)',
#   'Murphy',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '340799', 'True Lies', '1994', '7'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['341916', 'Adam (I)', 'Nelson', 'M', '387728', 'ER', '1994', '7.7'],
#  ['341916',
#   'Adam (I)',
#   'Nelson',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '5306',
#   'Abyss, The',
#   '1989',
#   '7.4'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '96779',
#   'Earthship.TV',
#   '2001',
#   '5.6'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '340799', 'True Lies', '1994', '7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '369522',
#   'Xenogenesis',
#   '1978',
#   '3.9'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '385710',
#   'Dark Angel',
#   '2000',
#   '7.4'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '30431',
#   'Barry Lyndon',
#   '1975',
#   '7.9'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '106666',
#   'Eyes Wide Shut',
#   '1999',
#   '7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '116239',
#   'Flying Padre',
#   '1951',
#   '5.9'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '176891',
#   "Killer's Kiss",
#   '1955',
#   '6.6'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '177019',
#   'Killing, The',
#   '1956',
#   '8.1'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '250612',
#   'Paths of Glory',
#   '1957',
#   '8.6'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '291833',
#   'Seafarers, The',
#   '1953',
#   '6.3'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '299073',
#   'Shining, The',
#   '1980',
#   '8.2'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '118367',
#   'Four Rooms',
#   '1995',
#   '5.9'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '164572',
#   'Jackie Brown',
#   '1997',
#   '7.5'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '267038',
#   'Pulp Fiction',
#   '1994',
#   '8.7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '276217',
#   'Reservoir Dogs',
#   '1992',
#   '8.3'],
#  ['342314', 'Joseph C.', 'Nemec III', 'M', '387728', 'ER', '1994', '7.7'],
#  ['342314',
#   'Joseph C.',
#   'Nemec III',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['386373', 'J.C.', 'Quinn', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['386373', 'J.C.', 'Quinn', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['386373', 'J.C.', 'Quinn', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['386373', 'J.C.', 'Quinn', 'M', '328285', 'Terminator, The', '1984', '7.9'],
#  ['386373', 'J.C.', 'Quinn', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['386373', 'J.C.', 'Quinn', 'M', '340799', 'True Lies', '1994', '7'],
#  ['386373', 'J.C.', 'Quinn', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['386373', 'J.C.', 'Quinn', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['386373', 'J.C.', 'Quinn', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['386373', 'J.C.', 'Quinn', 'M', '79846', 'Day of the Fight', '1951', '6.3'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['386373', 'J.C.', 'Quinn', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['386373', 'J.C.', 'Quinn', 'M', '110246', 'Fear and Desire', '1953', '6.1'],
#  ['386373', 'J.C.', 'Quinn', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['386373', 'J.C.', 'Quinn', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['386373', 'J.C.', 'Quinn', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['386373', 'J.C.', 'Quinn', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['386373', 'J.C.', 'Quinn', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
#  ['386373', 'J.C.', 'Quinn', 'M', '291833', 'Seafarers, The', '1953', '6.3'],
#  ['386373', 'J.C.', 'Quinn', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['386373', 'J.C.', 'Quinn', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['386373', 'J.C.', 'Quinn', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['386373', 'J.C.', 'Quinn', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['386373', 'J.C.', 'Quinn', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['386373', 'J.C.', 'Quinn', 'M', '276217', 'Reservoir Dogs', '1992', '8.3'],
#  ['386373', 'J.C.', 'Quinn', 'M', '387728', 'ER', '1994', '7.7'],
#  ['386373',
#   'J.C.',
#   'Quinn',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ['391009', 'Peter', 'Ratray', 'M', '5306', 'Abyss, The', '1989', '7.4'],
#  ['391009', 'Peter', 'Ratray', 'M', '10920', 'Aliens', '1986', '8.2'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '10934',
#   'Aliens of the Deep',
#   '2005',
#   '6.5'],
#  ['391009', 'Peter', 'Ratray', 'M', '96779', 'Earthship.TV', '2001', '5.6'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '105938',
#   'Expedition: Bismarck',
#   '2002',
#   '7.5'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '127297',
#   'Ghosts of the Abyss',
#   '2003',
#   '6.7'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '256530',
#   'Piranha Part Two: The Spawning',
#   '1981',
#   '2.8'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '322652',
#   'T2 3-D: Battle Across Time',
#   '1996',
#   '7.4'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '328277',
#   'Terminator 2: Judgment Day',
#   '1991',
#   '8.1'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '328285',
#   'Terminator, The',
#   '1984',
#   '7.9'],
#  ['391009', 'Peter', 'Ratray', 'M', '333856', 'Titanic', '1997', '6.9'],
#  ['391009', 'Peter', 'Ratray', 'M', '340799', 'True Lies', '1994', '7'],
#  ['391009', 'Peter', 'Ratray', 'M', '369522', 'Xenogenesis', '1978', '3.9'],
#  ['391009', 'Peter', 'Ratray', 'M', '385710', 'Dark Angel', '2000', '7.4'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '1711',
#   '2001: A Space Odyssey',
#   '1968',
#   '8.3'],
#  ['391009', 'Peter', 'Ratray', 'M', '30431', 'Barry Lyndon', '1975', '7.9'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '65764',
#   'Clockwork Orange, A',
#   '1971',
#   '8.3'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '79846',
#   'Day of the Fight',
#   '1951',
#   '6.3'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '92616',
#   'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   '1964',
#   '8.7'],
#  ['391009', 'Peter', 'Ratray', 'M', '106666', 'Eyes Wide Shut', '1999', '7'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '110246',
#   'Fear and Desire',
#   '1953',
#   '6.1'],
#  ['391009', 'Peter', 'Ratray', 'M', '116239', 'Flying Padre', '1951', '5.9'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '121538',
#   'Full Metal Jacket',
#   '1987',
#   '8.2'],
#  ['391009', 'Peter', 'Ratray', 'M', '176891', "Killer's Kiss", '1955', '6.6'],
#  ['391009', 'Peter', 'Ratray', 'M', '177019', 'Killing, The', '1956', '8.1'],
#  ['391009', 'Peter', 'Ratray', 'M', '193519', 'Lolita', '1962', '7.6'],
#  ['391009', 'Peter', 'Ratray', 'M', '250612', 'Paths of Glory', '1957', '8.6'],
#  ['391009', 'Peter', 'Ratray', 'M', '291833', 'Seafarers, The', '1953', '6.3'],
#  ['391009', 'Peter', 'Ratray', 'M', '299073', 'Shining, The', '1980', '8.2'],
#  ['391009', 'Peter', 'Ratray', 'M', '310455', 'Spartacus', '1960', '8'],
#  ['391009', 'Peter', 'Ratray', 'M', '118367', 'Four Rooms', '1995', '5.9'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '159665',
#   'Inglorious Bastards',
#   '2006',
#   '8.3'],
#  ['391009', 'Peter', 'Ratray', 'M', '164572', 'Jackie Brown', '1997', '7.5'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '176711',
#   'Kill Bill: Vol. 1',
#   '2003',
#   '8.4'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '176712',
#   'Kill Bill: Vol. 2',
#   '2004',
#   '8.2'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '223710',
#   "My Best Friend's Birthday",
#   '1987',
#   '3.9'],
#  ['391009', 'Peter', 'Ratray', 'M', '267038', 'Pulp Fiction', '1994', '8.7'],
#  ['391009', 'Peter', 'Ratray', 'M', '276217', 'Reservoir Dogs', '1992', '8.3'],
#  ['391009', 'Peter', 'Ratray', 'M', '387728', 'ER', '1994', '7.7'],
#  ['391009',
#   'Peter',
#   'Ratray',
#   'M',
#   '393538',
#   'Jimmy Kimmel Live!',
#   '2003',
#   '6.7'],
#  ...]

# %% [markdown]
# Finally, lets print the name of actors and the name of movies they have had a role in it.

# %%
# ADD CODE
# This is an example of the operation required, to do it to the entire database takes a while 
# because there are at least 1 million rows (takes about 4-5 minutes on my machine)
# This shows the algorithm in place for a single actor and single movie.
actors_and_roles = crossproduct(actors,roles)
actors_and_mid = project(intersection(selection(actors_and_roles,4,'10963','=='),selection(actors_and_roles,0,'10963','==')),[1,2,5])
actors_and_movies = crossproduct(actors_and_mid, movies)
actors_and_movies_in = selection(actors_and_movies,3,'5306','==')
actors_and_movies_in
print(project(actors_and_movies_in,[0,1,4]))
# Out:
# [['Chris', 'Anastasio', 'Abyss, The']]

# %%
actor_ids = project(actors,[0])
actors_and_roles = crossproduct(actors,roles)
actors_and_mid = []
actors_and_movies_in = []
for a_id in actor_ids:
    temp = intersection(selection(actors_and_roles,4,a_id[0],'=='),selection(actors_and_roles,0,a_id[0],'=='))
    actors_and_mid = union2(actors_and_mid, temp)
actors_and_movies = project(crossproduct(actors_and_mid,movies),[1,2,5,7,8])
actors_and_movies2 = []
for i in actors_and_movies:
    if i not in actors_and_movies2:
        actors_and_movies2.append(i)
actors_and_movies2
temp_lst = []
for i in actors_and_movies2:
    if i[2] == i[3]:
        temp_lst.append(i)
final_lst = project(temp_lst,[0,1,4])
for i in final_lst:
    print(i[0],i[1],i[2])
# Out:
# Chris Anastasio Abyss, The
# Michael Beach Abyss, The
# John Bedford Lloyd Abyss, The
# Michael Biehn Abyss, The
# Michael Biehn Aliens
# Michael Biehn T2 3-D: Battle Across Time
# Michael Biehn Terminator 2: Judgment Day
# Michael Biehn Terminator, The
# Captain Kidd Brewer Jr. Abyss, The
# Captain Kidd Brewer Jr. Piranha Part Two: The Spawning
# Leo Burmester Abyss, The
# Mike (I) Cameron Abyss, The
# Mike (I) Cameron Ghosts of the Abyss
# Mike (I) Cameron True Lies
# J. Kenneth Campbell Abyss, The
# Michael (I) Chapman Abyss, The
# Phillip Darlington Abyss, The
# Thomas F. Duffy Abyss, The
# Chris (I) Elliott Abyss, The
# Joe Farago Abyss, The
# Joe Farago Terminator, The
# Todd Graff Abyss, The
# Ed (I) Harris Abyss, The
# Tom Isbell Abyss, The
# Tom Isbell True Lies
# Ken (I) Jenkins Abyss, The
# George Robert Klek Abyss, The
# Frank (II) Lloyd Abyss, The
# Marcus K. Mukai Abyss, The
# Christopher (I) Murphy Abyss, The
# Adam (I) Nelson Abyss, The
# Shawn Schepps Terminator, The
# Seth (I) Adkins Titanic
# Scott G. Anderson Titanic
# Kris Andersson Titanic
# Richard (II) Ashton Titanic
# Jason Barry Titanic
# Eric Braeden Titanic
# Paul Brightwell Titanic
# Mike Butters Titanic
# Chris (I) Byrne Titanic
# Bruno Campolo Titanic
# Mark Capri Titanic
# Nicholas Cascone Titanic
# Aaron James Cash Titanic
# Marc Cass Titanic
# Mark Lindsay Chapman Titanic
# Brendan Connolly Titanic
# Gregory (I) Cooke Titanic
# Chris Cragnotti Titanic
# Simon (I) Crane Titanic
# David Cronnelly Titanic
# Barry Dennen Titanic
# Barry Dennen Shining, The
# Leonardo DiCaprio Titanic
# Ron Donachie Titanic
# Shay Duffin Titanic
# Martin East Titanic
# Greg (II) Ellis Titanic
# Michael Ensign Titanic
# Jonathan Evans-Jones Titanic
# Anders (I) Falk Titanic
# Edward Fletcher Titanic
# Terry Forestal Titanic
# Edmund Alan Forsyth Titanic
# Bernard (I) Fox Titanic
# Richard (I) Fox Titanic
# Romeo Francis Titanic
# Thomas FÃ¼ri Titanic
# Victor Garber Titanic
# James (IV) Garrett Titanic
# Werner Giger Titanic
# Richard (I) Graham Titanic
# Ioan Gruffudd Titanic
# Lorenz Hasler Titanic
# Paul (IV) Herbert Titanic
# Bernard Hill Titanic
# Scott Hislop Titanic
# Erik Holland Titanic
# Martin Hub Titanic
# Jonathan Hyde Titanic
# Emmett James Titanic
# Martin Jarvis Titanic
# Rudy Joffroy Titanic
# Craig (II) Kelly Titanic
# Tony (I) Kenny Titanic
# Jari (I) Kinnunen Titanic
# Martin (I) Laing Titanic
# James Lancaster Titanic
# Derek Lea Titanic
# Shep Lonsdale Titanic
# Johnny (I) Martin Titanic
# Stan Mazin Titanic
# Nick Meaney Titanic
# Patrick (IV) Murphy Titanic
# Sean Nepita Titanic
# Danny Nucci Titanic
# Mike (II) O'Neal Titanic
# BjÃ¸rn (I) Olsen Titanic
# Kevin Owers Titanic
# Oliver Page Titanic
# Lew Palter Titanic
# Dan (I) Pettersson Titanic
# Jonathan (I) Phillips Titanic
# Stephen Wolfe Smith Titanic
# Ewan (I) Stewart Titanic
# BÃ©la SzedlÃ¡k Titanic
# Ferenc SzedlÃ¡k Titanic
# Rocky (I) Taylor Titanic
# Reece P. Thompson III Titanic
# R. Gern Trowbridge Titanic
# Mark Rafael Truitt Titanic
# Liam Tuohy Titanic
# Stephen Twigger Titanic
# Vern Urich Titanic
# Francisco VÃ¡ldez Titanic
# John Walcutt Titanic
# Brian (II) Walsh Titanic
# David (I) Warner Titanic
# Stephen Wehmeyer Titanic
# Garth Wilton Titanic
# Billy Zane Titanic
# Suzy Amis Titanic
# Rosalind Ayres Titanic
# Bobbie Bates Titanic
# Kathy (I) Bates Titanic
# Dawn M. Bourn Titanic
# Alexandra Boyd Titanic
# Fannie Brett Titanic
# Charlotte Chatton Titanic
# Kathleen S. Dunn Titanic
# Frances (I) Fisher Titanic
# Anne Fletcher Titanic
# Amy Gaipa Titanic
